# %% [markdown]
# ---

# %% [markdown]
# https://github.com/meta-llama/llama-recipes/blob/v0.0.3/recipes/quickstart/finetuning/quickstart_peft_finetuning.ipynb 를 복사해서 수정함.
#
# pip install llama-recipes 실행 시, 0.0.3 버전이 설치 되기 때문에,
# quickstart_peft_finetuning.ipynb 파일도 0.0.3 버전을 사용해야 문제 없이 실행이 됨!

# %% [markdown]
# ---

# %% [markdown]
# Copyright (c) Meta Platforms, Inc. and affiliates.
# This software may be used and distributed according to the terms of the Llama 2 Community License Agreement.
#
# <a href="https://colab.research.google.com/github/meta-llama/llama-recipes/blob/main/recipes/finetuning/quickstart_peft_finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PEFT Finetuning Quick Start Notebook
#
# This notebook shows how to train a Meta Llama 3 model on a single GPU (e.g. A10 with 24GB) using int8 quantization and LoRA finetuning.
#
# **_Note:_** To run this notebook on a machine with less than 24GB VRAM (e.g. T4 with 16GB) the context length of the training dataset needs to be adapted.
# We do this based on the available VRAM during execution.
# If you run into OOM issues try to further lower the value of train_config.context_length.

# %% [markdown]
# ### Step 0: Install pre-requirements and convert checkpoint
#
# We need to have llama-recipes and its dependencies installed for this notebook. Additionally, we need to log in with the huggingface_cli and make sure that the account is able to to access the Meta Llama weights.

# %%
# uncomment if running from Colab T4
# ! pip install llama-recipes ipywidgets

# import huggingface_hub
# huggingface_hub.login()

# %% [markdown]
# ### Step 1: Load the model
#
# Setup training configuration and load the model and tokenizer.

# %%
import torch
from transformers import LlamaForCausalLM, AutoTokenizer
from llama_recipes.configs import train_config as TRAIN_CONFIG

train_config = TRAIN_CONFIG()
train_config.model_name = "meta-llama/Meta-Llama-3.1-8B"
train_config.num_epochs = 1
train_config.run_validation = False
train_config.gradient_accumulation_steps = 4
train_config.batch_size_training = 1
train_config.lr = 3e-4
train_config.use_fast_kernels = True
train_config.use_fp16 = True
train_config.context_length = 1024 if torch.cuda.get_device_properties(0).total_memory < 16e9 else 2048 # T4 16GB or A10 24GB
train_config.batching_strategy = "packing"
train_config.output_dir = "meta-llama-samsum"

from transformers import BitsAndBytesConfig
config = BitsAndBytesConfig(
    load_in_8bit=True,
)

model = LlamaForCausalLM.from_pretrained(
            train_config.model_name,
            device_map="auto",
            quantization_config=config,
            use_cache=False,
            attn_implementation="sdpa" if train_config.use_fast_kernels else None,
            torch_dtype=torch.float16,
        )

tokenizer = AutoTokenizer.from_pretrained(train_config.model_name)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Step 2: Check base model
#
# Run the base model on an example input:

# %%
eval_prompt = """
Summarize this dialog:
#Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
#Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
#Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
#Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
#Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
#Person2#: 알겠습니다.
#Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
#Person2#: 네.
#Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다. 
#Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
#Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
#Person2#: 알겠습니다, 감사합니다, 의사선생님.
---
Summary:
"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

model.eval()
with torch.no_grad():
    generated = model.generate(**model_input, max_new_tokens=100)
    print(tokenizer.decode(generated[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Summarize this dialog:
# #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
# #Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
# #Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
# #Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
# #Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
# #Person2#: 알겠습니다.
# #Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
# #Person2#: 네.
# #Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다.
# #Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
# #Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
# #Person2#: 알겠습니다, 감사합니다, 의사선생님.
# ---
# Summary:
# #Person1#: Hello, Mr. Smith. I'm Dr. Hawkins. Why did you come today?
# #Person2#: I thought I should get a checkup.
# #Person1#: You haven't had one in 5 years. You should have one every year.
# #Person2#: I know. But why should I see a doctor if I'm healthy?
# #Person1#: The best way to prevent serious illness is to detect it early. So, for your health, you should

# %% [markdown]
# We can see that the base model only repeats the conversation.
#
# ### Step 3: Load the preprocessed dataset
#
# We load and preprocess the samsum dataset which consists of curated pairs of dialogs and their summarization:

# %%
from torch.utils.data import Dataset
import pandas as pd

class DatasetForLlamaTrain(Dataset):
    def __init__(self, train_csv_fullpath):
        df = pd.read_csv(train_csv_fullpath)
        
        prompt = (
            f"Summarize this dialog:\n{{dialog}}\n---\nSummary:\n"
        )

        def apply_prompt_template(s):
            return prompt.format(dialog=s)

        df['dialogue'] = df['dialogue'].map(apply_prompt_template)

        self.preprocessed_list = []
        
        for i in range(len(df)):
            processed_row = {}
            
            prompt = tokenizer.encode(tokenizer.bos_token + df.iloc[i]['dialogue'], add_special_tokens=False)
            summary = tokenizer.encode(df.iloc[i]['summary'] +  tokenizer.eos_token, add_special_tokens=False)
            
            processed_row = {
                "input_ids": prompt + summary,
                "attention_mask" : [1] * (len(prompt) + len(summary)),
                "labels": [-100] * len(prompt) + summary,
            }
            
            self.preprocessed_list.append(processed_row)
        
        self.len = len(self.preprocessed_list)

    def __getitem__(self, idx):
        return self.preprocessed_list[idx]

    def __len__(self):
        return self.len

# %%
#from llama_recipes.configs.datasets import samsum_dataset
from llama_recipes.data.concatenator import ConcatDataset
from llama_recipes.utils.config_utils import get_dataloader_kwargs
#from llama_recipes.utils.dataset_utils import get_preprocessed_dataset

train_dataset = DatasetForLlamaTrain('../../data/train.csv')

train_dl_kwargs = get_dataloader_kwargs(train_config, train_dataset, tokenizer, "train")

if train_config.batching_strategy == "packing":
        train_dataset = ConcatDataset(train_dataset, chunk_size=train_config.context_length)

# Create DataLoaders for the training and validation dataset
train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    num_workers=train_config.num_workers_dataloader,
    pin_memory=True,
    **train_dl_kwargs,
)
# Out:
# Preprocessing dataset: 100%|██████████| 12457/12457 [00:00<00:00, 43242.11it/s]

# %% [markdown]
# ### Step 4: Prepare model for PEFT
#
# Let's prepare the model for Parameter Efficient Fine Tuning (PEFT):

# %%
from peft import get_peft_model, prepare_model_for_kbit_training, LoraConfig
from dataclasses import asdict
from llama_recipes.configs import lora_config as LORA_CONFIG

lora_config = LORA_CONFIG()
lora_config.r = 8
lora_config.lora_alpha = 32
lora_dropout: float=0.01

peft_config = LoraConfig(**asdict(lora_config))

model = prepare_model_for_kbit_training(model)
model = get_peft_model(model, peft_config)

# %% [markdown]
# ### Step 5: Fine tune the model
#
# Here, we fine tune the model for a single epoch.

# %%
import torch.optim as optim
from llama_recipes.utils.train_utils import train
from torch.optim.lr_scheduler import StepLR

model.train()

optimizer = optim.AdamW(
            model.parameters(),
            lr=train_config.lr,
            weight_decay=train_config.weight_decay,
        )
scheduler = StepLR(optimizer, step_size=1, gamma=train_config.gamma)

# Start the training process
results = train(
    model,
    train_dataloader,
    None,
    tokenizer,
    optimizer,
    scheduler,
    train_config.gradient_accumulation_steps,
    train_config,
    None,
    None,
    None,
    wandb_run=None,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/llama_recipes/utils/train_utils.py:92: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /opt/conda/lib/python3.10/site-packages/torch/cuda/memory.py:343: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Training Epoch: 1:   0%|          | 0/448 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /opt/conda/lib/python3.10/site-packages/llama_recipes/utils/train_utils.py:151: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /opt/conda/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/bitsandbytes/autograd/_functions.py:316: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# Training Epoch: 1/1, step 1791/1792 completed (loss: 0.22924171388149261): 100%|██████████| 448/448 [1:27:45<00:00, 11.75s/it]
# Max CUDA memory allocated was 15 GB
# Max CUDA memory reserved was 16 GB
# Peak active CUDA memory was 15 GB
# CUDA Malloc retries : 0
# CPU Total Peak Memory consumed during the train (max): 2 GB
# Epoch 1: train_perplexity=1.2751, train_epoch_loss=0.2430, epoch time 5265.642416089773s

# %% [markdown]
# ### Step 6:
# Save model checkpoint

# %%
model.save_pretrained(train_config.output_dir)

# %% [markdown]
# ### Step 7:
# Try the fine tuned model on the same example again to see the learning progress:

# %%
model.eval()
with torch.no_grad():
    print(tokenizer.decode(model.generate(**model_input, max_new_tokens=100)[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Summarize this dialog:
# #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
# #Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
# #Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
# #Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
# #Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
# #Person2#: 알겠습니다.
# #Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
# #Person2#: 네.
# #Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다.
# #Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
# #Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
# #Person2#: 알겠습니다, 감사합니다, 의사선생님.
# ---
# Summary:
# 스미스씨는 건강검진을 받기 위해 의사에게 방문했습니다. 호킨스 의사는 스미스씨에게 매년 한 번은 오는 것이 좋다고 말했습니다. 스미스씨는 담배를 끊으려고 하지만, 습관을 버리는 것이 어렵다고 말했습니다.

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# 이 아래를 실행하기 전에 메모리 확보를 위해 커널을 재시작 할 것!

# %%
import os
import random
import torch

def set_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    #np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True

set_seed(42)

# %%
# https://huggingface.co/blog/peft 이 글에서 학습한걸 읽는 코드를 참고해서 작성함.

import torch
from transformers import LlamaForCausalLM, AutoTokenizer
from llama_recipes.configs import train_config as TRAIN_CONFIG
from peft import PeftModel, PeftConfig

device = torch.device('cuda:0' if torch.cuda.is_available()  else 'cpu')
peft_model_id = "meta-llama-samsum"
peftConfig = PeftConfig.from_pretrained(peft_model_id)

from transformers import BitsAndBytesConfig
config = BitsAndBytesConfig(
    load_in_8bit=True,
)

model = LlamaForCausalLM.from_pretrained(
            peftConfig.base_model_name_or_path,
            device_map="auto",
            quantization_config=config,
            use_cache=False,
            torch_dtype=torch.float16,
        )
model = PeftModel.from_pretrained(model, peft_model_id)
model = model.to(device)

tokenizer = AutoTokenizer.from_pretrained(peftConfig.base_model_name_or_path)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
eval_prompt = """
Summarize this dialog:
#Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
#Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
#Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
#Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
#Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
#Person2#: 알겠습니다.
#Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
#Person2#: 네.
#Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다. 
#Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
#Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
#Person2#: 알겠습니다, 감사합니다, 의사선생님.
---
Summary:
"""

model_input = tokenizer(eval_prompt, return_tensors="pt").to("cuda")

model.eval()
with torch.no_grad():
    generated = model.generate(**model_input, max_new_tokens=100)
    print(tokenizer.decode(generated[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Summarize this dialog:
# #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나요?
# #Person2#: 건강검진을 받는 것이 좋을 것 같아서요.
# #Person1#: 그렇군요, 당신은 5년 동안 건강검진을 받지 않았습니다. 매년 받아야 합니다.
# #Person2#: 알고 있습니다. 하지만 아무 문제가 없다면 왜 의사를 만나러 가야 하나요?
# #Person1#: 심각한 질병을 피하는 가장 좋은 방법은 이를 조기에 발견하는 것입니다. 그러니 당신의 건강을 위해 최소한 매년 한 번은 오세요.
# #Person2#: 알겠습니다.
# #Person1#: 여기 보세요. 당신의 눈과 귀는 괜찮아 보입니다. 깊게 숨을 들이쉬세요. 스미스씨, 담배 피우시나요?
# #Person2#: 네.
# #Person1#: 당신도 알다시피, 담배는 폐암과 심장병의 주요 원인입니다. 정말로 끊으셔야 합니다.
# #Person2#: 수백 번 시도했지만, 습관을 버리는 것이 어렵습니다.
# #Person1#: 우리는 도움이 될 수 있는 수업과 약물들을 제공하고 있습니다. 나가기 전에 더 많은 정보를 드리겠습니다.
# #Person2#: 알겠습니다, 감사합니다, 의사선생님.
# ---
# Summary:
# 호킨스 의사는 스미스씨에게 건강검진을 받으라고 권하고, 그가 담배를 끊으라고 조언합니다.

# %%
from torch.utils.data import Dataset
import pandas as pd

class DatasetForLlamaTest(Dataset):
    def __init__(self, train_csv_fullpath):
        df = pd.read_csv(train_csv_fullpath)
        
        prompt = (
            f"Summarize this dialog:\n{{dialog}}\n---\nSummary:\n"
        )

        def apply_prompt_template(s):
            return prompt.format(dialog=s)

        df['dialogue'] = df['dialogue'].map(apply_prompt_template)

        self.fname_list = []
        self.preprocessed_list = []
        
        for i in range(len(df)):
            #
            self.fname_list.append(df.iloc[i]['fname'])
            
            # tokenizer() 와 tokenizer.encode() 는 다르다!
            # tokenizer() 를 사용해야 딕셔너리(input_ids, attention_mask) 형태로 리턴됨.
            prompt = tokenizer(df.iloc[i]['dialogue'], return_tensors="pt").to("cuda")
            self.preprocessed_list.append(prompt)
        
        self.len = len(self.preprocessed_list)

    def __getitem__(self, idx):
        return self.fname_list[idx], self.preprocessed_list[idx]

    def __len__(self):
        return self.len

# %%
train_dataset = DatasetForLlamaTest('../../data/test.csv')

# %%
import re
from tqdm import tqdm

fname_list = []
summary_list = []

model.eval()
with torch.no_grad():
    for fname, model_input in tqdm(train_dataset):
        generated = model.generate(**model_input, max_new_tokens=100)
        decoded_str = tokenizer.decode(generated[0], skip_special_tokens=True)
        
        summary = decoded_str.split('Summary:\n')[1]
        
        # \n 제거
        summary = re.sub('\n', '', summary)
        
        fname_list.append(fname)
        summary_list.append(summary)
# Out:
#   0%|          | 0/499 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 1/499 [00:17<2:24:30, 17.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 2/499 [00:29<1:57:37, 14.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 3/499 [00:37<1:34:50, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 4/499 [00:47<1:29:50, 10.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 5/499 [00:56<1:23:12, 10.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 6/499 [01:12<1:38:48, 12.03s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 7/499 [01:22<1:34:57, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 8/499 [01:32<1:30:09, 11.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 9/499 [01:44<1:31:46, 11.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 10/499 [01:55<1:30:51, 11.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 11/499 [02:01<1:19:15,  9.74s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 12/499 [02:12<1:21:40, 10.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 13/499 [02:24<1:27:06, 10.75s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 14/499 [02:31<1:15:54,  9.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 15/499 [02:41<1:17:11,  9.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 16/499 [02:51<1:18:36,  9.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 17/499 [02:59<1:15:18,  9.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 18/499 [03:09<1:16:04,  9.49s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 19/499 [03:17<1:12:36,  9.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 20/499 [03:23<1:04:17,  8.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 21/499 [03:33<1:08:20,  8.58s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 22/499 [03:45<1:17:16,  9.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 23/499 [03:50<1:04:57,  8.19s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 24/499 [03:55<58:11,  7.35s/it]  Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 25/499 [04:01<54:25,  6.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 26/499 [04:17<1:15:27,  9.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 27/499 [04:27<1:16:59,  9.79s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 28/499 [04:35<1:12:45,  9.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 29/499 [04:49<1:23:45, 10.69s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 30/499 [04:55<1:13:06,  9.35s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 31/499 [05:06<1:16:18,  9.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 32/499 [05:12<1:07:51,  8.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 33/499 [05:24<1:14:21,  9.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 34/499 [05:35<1:17:38, 10.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 35/499 [05:41<1:07:46,  8.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 36/499 [05:49<1:05:37,  8.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 37/499 [06:01<1:13:12,  9.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 38/499 [06:06<1:02:42,  8.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 39/499 [06:17<1:10:04,  9.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 40/499 [06:29<1:15:51,  9.92s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 41/499 [06:36<1:09:49,  9.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 42/499 [06:49<1:17:45, 10.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 43/499 [07:00<1:19:16, 10.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 44/499 [07:14<1:27:07, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 45/499 [07:28<1:34:20, 12.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 46/499 [07:42<1:36:46, 12.82s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 47/499 [07:51<1:27:29, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 48/499 [08:02<1:26:39, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 49/499 [08:08<1:14:10,  9.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 50/499 [08:16<1:09:55,  9.34s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 51/499 [08:26<1:10:33,  9.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 52/499 [08:32<1:03:31,  8.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 53/499 [08:43<1:09:03,  9.29s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 54/499 [08:49<1:00:54,  8.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         |
30s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|████████▉ | 447/499 [1:12:11<10:20, 11.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|████████▉ | 448/499 [1:12:18<08:58, 10.56s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|████████▉ | 449/499 [1:12:25<07:47,  9.34s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 450/499 [1:12:38<08:29, 10.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 451/499 [1:12:47<08:06, 10.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████ | 452/499 [1:12:52<06:45,  8.62s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████ | 453/499 [1:12:56<05:36,  7.32s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████ | 454/499 [1:13:02<04:59,  6.66s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████ | 455/499 [1:13:05<04:17,  5.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████▏| 456/499 [1:13:11<04:09,  5.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 457/499 [1:13:24<05:27,  7.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 458/499 [1:13:32<05:20,  7.82s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 459/499 [1:13:35<04:26,  6.66s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 460/499 [1:13:52<06:19,  9.73s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 461/499 [1:14:00<05:47,  9.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 462/499 [1:14:06<05:07,  8.30s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 463/499 [1:14:16<05:09,  8.61s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 464/499 [1:14:20<04:19,  7.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 465/499 [1:14:40<06:14, 11.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 466/499 [1:14:45<05:02,  9.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 467/499 [1:14:51<04:30,  8.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 468/499 [1:15:09<05:47, 11.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 469/499 [1:15:28<06:46, 13.54s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 470/499 [1:15:37<05:51, 12.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 471/499 [1:15:57<06:42, 14.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 472/499 [1:16:09<06:10, 13.71s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 473/499 [1:16:13<04:42, 10.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 474/499 [1:16:28<05:01, 12.08s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 475/499 [1:16:42<05:06, 12.75s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 476/499 [1:16:49<04:13, 11.02s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 477/499 [1:16:59<03:51, 10.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 478/499 [1:17:10<03:48, 10.86s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 479/499 [1:17:20<03:31, 10.56s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 480/499 [1:17:34<03:38, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 481/499 [1:17:56<04:25, 14.74s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 482/499 [1:18:05<03:43, 13.14s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 483/499 [1:18:24<03:58, 14.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 484/499 [1:18:48<04:23, 17.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 485/499 [1:18:51<03:05, 13.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 486/499 [1:18:57<02:21, 10.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 487/499 [1:19:05<02:01, 10.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 488/499 [1:19:11<01:36,  8.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 489/499 [1:19:23<01:38,  9.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 490/499 [1:19:30<01:19,  8.81s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 491/499 [1:19:47<01:29, 11.25s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 492/499 [1:19:52<01:06,  9.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 493/499 [1:20:00<00:55,  9.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 494/499 [1:20:08<00:43,  8.74s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 495/499 [1:20:15<00:32,  8.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 496/499 [1:20:25<00:26,  8.86s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 497/499 [1:20:41<00:21, 10.79s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 498/499 [1:20:48<00:09,  9.83s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 499/499 [1:21:00<00:00,  9.74s/it]

# %%
print(fname_list)
print(summary_list)
# Out:
# ['test_0', 'test_1', 'test_2', 'test_3', 'test_4', 'test_5', 'test_6', 'test_7', 'test_8', 'test_9', 'test_10', 'test_11', 'test_12', 'test_13', 'test_14', 'test_15', 'test_16', 'test_17', 'test_18', 'test_19', 'test_20', 'test_21', 'test_22', 'test_23', 'test_24', 'test_25', 'test_26', 'test_27', 'test_28', 'test_29', 'test_30', 'test_31', 'test_32', 'test_33', 'test_34', 'test_35', 'test_36', 'test_37', 'test_38', 'test_39', 'test_40', 'test_41', 'test_42', 'test_43', 'test_44', 'test_45', 'test_46', 'test_47', 'test_48', 'test_49', 'test_50', 'test_51', 'test_52', 'test_53', 'test_54', 'test_55', 'test_56', 'test_57', 'test_58', 'test_59', 'test_60', 'test_61', 'test_62', 'test_63', 'test_64', 'test_65', 'test_66', 'test_67', 'test_68', 'test_69', 'test_70', 'test_71', 'test_72', 'test_73', 'test_74', 'test_75', 'test_76', 'test_77', 'test_78', 'test_79', 'test_80', 'test_81', 'test_82', 'test_83', 'test_84', 'test_85', 'test_86', 'test_87', 'test_88', 'test_89', 'test_90', 'test_91', 'test_92', 'test_93', 'test_94', 'test_95', 'test_96', 'test_97', 'test_98', 'test_99', 'test_100', 'test_101', 'test_102', 'test_103', 'test_104', 'test_105', 'test_106', 'test_107', 'test_108', 'test_109', 'test_110', 'test_111', 'test_112', 'test_113', 'test_114', 'test_115', 'test_116', 'test_117', 'test_118', 'test_119', 'test_120', 'test_121', 'test_122', 'test_123', 'test_124', 'test_125', 'test_126', 'test_127', 'test_128', 'test_129', 'test_130', 'test_131', 'test_132', 'test_133', 'test_134', 'test_135', 'test_136', 'test_137', 'test_138', 'test_139', 'test_140', 'test_141', 'test_142', 'test_143', 'test_144', 'test_145', 'test_146', 'test_147', 'test_148', 'test_149', 'test_150', 'test_151', 'test_152', 'test_153', 'test_154', 'test_155', 'test_156', 'test_157', 'test_158', 'test_159', 'test_160', 'test_161', 'test_162', 'test_163', 'test_164', 'test_165', 'test_166', 'test_167', 'test_168', 'test_169', 'test_170', 'test_171', 'test_172', 'test_173', 'test_174', 'test_175', 'test_176', 'test_177', 'test_178', 'test_179', 'test_180', 'test_181', 'test_182', 'test_183', 'test_184', 'test_185', 'test_186', 'test_187', 'test_188', 'test_189', 'test_190', 'test_191', 'test_192', 'test_193', 'test_194', 'test_195', 'test_196', 'test_197', 'test_198', 'test_199', 'test_200', 'test_201', 'test_202', 'test_203', 'test_204', 'test_205', 'test_206', 'test_207', 'test_208', 'test_209', 'test_210', 'test_211', 'test_212', 'test_213', 'test_214', 'test_215', 'test_216', 'test_217', 'test_218', 'test_219', 'test_220', 'test_221', 'test_222', 'test_223', 'test_224', 'test_225', 'test_226', 'test_227', 'test_228', 'test_229', 'test_230', 'test_231', 'test_232', 'test_233', 'test_234', 'test_235', 'test_236', 'test_237', 'test_238', 'test_239', 'test_240', 'test_241', 'test_242', 'test_243', 'test_244', 'test_245', 'test_246', 'test_247', 'test_248', 'test_249', 'test_250', 'test_251', 'test_252', 'test_253', 'test_254', 'test_255', 'test_256', 'test_257', 'test_258', 'test_259', 'test_260', 'test_261', 'test_262', 'test_263', 'test_264', 'test_265', 'test_266', 'test_267', 'test_268', 'test_269', 'test_270', 'test_271', 'test_272', 'test_273', 'test_274', 'test_275', 'test_276', 'test_277', 'test_278', 'test_279', 'test_280', 'test_281', 'test_282', 'test_283', 'test_284', 'test_285', 'test_286', 'test_287', 'test_288', 'test_289', 'test_290', 'test_291', 'test_292', 'test_293', 'test_294', 'test_295', 'test_296', 'test_297', 'test_298', 'test_299', 'test_300', 'test_301', 'test_302', 'test_303', 'test_304', 'test_305', 'test_306', 'test_307', 'test_308', 'test_309', 'test_310', 'test_311', 'test_312', 'test_313', 'test_314', 'test_315', 'test_316', 'test_317', 'test_318', 'test_319', 'test_320', 'test_321', 'test_322', 'test_323', 'test_324', 'test_325', 'test_326', 'test_327', 'test_328', 'test_329', 'test_330', 'test_331', 'test_332', 'test_333', 'test_334', 'test_335', 'test_336', 'test_337', 'test_338', 'test_339', 'test_340', 'test_341', 'test ...
# ['#Person1#은 더슨 씨에게 내부 메모를 받아쓰도록 요청합니다. 더슨 씨는 메모를 시작하고 #Person1#은 모든 직원에게 주의하라고 요청합니다. 더슨 씨는 이메일 통신과 공식 메모로 모든 사무실 통신을 제한하도록 요청하고, 즉시 메시지 프로그램을 사용하는 것을 엄격히 금지합니다.', '#Person2#는 교통 체증에 걸려서 늦었다. #Person1#는 #Person2#에게 대중교통을 이용하거나 자전거를 타는 것을 제안한다. #Person2#는 그들이 환경에 더 좋을 것이라고 생각한다.', '#Person1#은 케이트에게 마샤와 히어로가 이혼하려고 한다고 말한다. 케이트는 놀라서 #Person1#에게 더 많은 정보를 요청한다.', '#Person1#은 브라이언의 생일을 축하하고, 브라이언은 #Person1#에게 춤을 추는 것을 요청한다. #Person1#은 브라이언에게 인사를 하고, 그들은 함께 술을 마실 것이다.', '#Person2#는 #Person1#에게 올림픽 공원의 중심인 올림픽 스타디움에 대해 설명하고, #Person1#는 그 크기에 놀라며 표지판을 보고 있습니다.', '#Person1#은 회사를 창업하기로 결정했다. #Person2#는 #Person1#에게 사업 계획서를 작성하는 방법을 알려준다. #Person1#은 투자자들에게 재무 분석을 포함하는 요약문을 작성해야 한다. #Person1#은 사업을 시작하는 모든 번거로움을 피하려고 한다.', '#Person1#은 #Person2#가 수두에 걸렸다고 생각하지만 #Person2#는 의사를 만나기 전에 확신할 수 없다고 생각한다. #Person1#은 #Person2#가 생물학적 위험요소라고 생각한다.', '#Person1#은 #Person2#에게 청구서를 제공하지만, #Person2#는 세탁 서비스 비용이 포함되어 있다는 것을 발견한다. #Person1#은 실수가 있었음을 인정하고 청구서를 수정한다.', '#Person1#의 아내는 #Person1#이 불륜을 저질렀다고 생각하고, #Person1#은 스티븐에게 도움을 청한다. 스티븐은 #Person1#에게 아내를 설득하도록 도와줄 것이다.', '#Person2#는 에이브러햄 링컨이 #Person2#의 마음 속에 있는 건전한 성격을 지닌 남자 또는 여자라고 생각합니다. #Person2#는 링컨이 평등한 권리를 위해 싸우는 용기를 존경합니다.', '#Person2#는 허베이를 방문하고 싶지만, #Person1#은 중국 북부에서 심각한 모래폭풍이 일어나고 있다고 말한다.', '#Person2#는 프란시스에게 리모컨 자동차 모델을 선물로 줍니다. 프란시스는 그것을 좋아하고, #Person2#는 항상 자신을 위해 가장 좋은 것을 갖고 싶어하는 전형적인 #Person2#라고 생각합니다.', '토니가 스티븐에게 부정행위로 걸렸다고 말한다. 토니는 열심히 공부해야 한다고 생각하지만, 그는 부정행위로 걸렸다. 스티븐은 토니에게 실수에서 배운다면 그걸로 충분하다고 말한다.', '#Person1#은 기차를 타기 위해 서둘러야 한다. #Person2#는 #Person1#에게 아직 시간이 많다고 말한다.', '#Person1#은 #Person2#에게 자신이 어떻게 살아야 할지 묻습니다. #Person2#는 #Person1#에게 충분한 수면을 취하고, 적게 마시고, 매일 아침 운동을 하라고 조언합니다.', '#Person1#은 루오지아의 결혼 파티에 초대되었다. #Person1#은 루오지아의 트위터와 이메일을 통해 파티에 초대되었다. #Person2#는 또한 초대장을 받았다.', '#Person1#은 적들을 만들고 #Person2#는 #Person1#의 친구가 될 수 없다고 생각한다. #Person2#는 #Person1#에게 서둘러 쏘라고 요청한다.', '마이크는 그의 누나에 대해 이야기한다. 마이크는 누나가 키가 크고 예쁘다고 생각하며, 그들은 친절하고 사교적이다. 하지만 마이크는 그녀가 똑똑하지 않다고 생각한다.', '#Person1#이 머리가 아프다. #Person2#는 #Person1#에게 체온계로 온도를 재고, #Person1#이 부모님에게 전화를 해야한다고 말한다.', '#Person2#는 새로운 휴대폰을 사고 싶어합니다. #Person1#는 #Person2#에게 몇 가지 질문을 합니다.', '프랭크는 주디에게 우체국에서 일하게 될 것이라고 말한다. 프랭크는 일정이 바쁘지만, 가족을 위한 훌륭한 건강보험 혜택을 제공한다는 것을 알고 있다.', '#Person2#는 #Person1#에게 컴퓨터 프로그램 작성, 비서 기술, 운전 면허, 의사 면허, 케임브리지 시험, 런던의 루카스 비서 대학, 사무 절차, 그리고 사무용 기기에 대한 교육을 받은 경험에 대해 이야기합니다.', '#Person1#은 스테이크가 너무 익혀져 있고 질겨서 바꿔달라고 요청합니다.', '#Person1#은 톰에게 그의 소설이 노벨상을 받았다고 말한다. 톰은 놀라며 감사한다.', '#Person2#는 자동차 디자인을 전공하고 과학 석사 학위를 받았기 때문에 이 일을 잘 할 수 있을 것이라고 생각합니다.', '#Person1#은 맥주 두 병만 마셔요. #Person2#는 밤새도록 10잔 이상 마셔요. #Person1#은 #Person2#가 많은 돈을 쓰지 않는다고 생각합니다. #Person2#는 칵테일을 권하고, #Person1#은 시간이 좀 걸리겠지만 연습 중입니다.', '#Person1#은 피크닉 준비를 돕기 위해 메이에게 물어봤습니다. 메이는 #Person1#에게 도와주겠다고 했지만, #Person1#은 다니엘에게 도움을 청하려고 합니다.', '제임스와 뮤리엘은 서로를 소개하고, 제임스의 휴가와 뮤리엘의 휴가에 대해 이야기합니다. 제임스는 수잔을 소개합니다.', '#Person1#은 ATM에서 돈을 인출하려고 하지만, ATM은 #Person1#의 돈을 이체하는 것을 요구한다. #Person1#은 화가 나서 ATM에 돈을 요구하지만, ATM은 #Person1#에게 돈을 주지 않고, #Person1#의 출구를 봉쇄한다.', '#Person2#는 #Person1#에게 #Person2#가 외향적인 사회적인 사람이며, 소통에서 가장 중요한 것은 진심이라고 말합니다.', '폴리 씨는 끔찍한 일에서 벗어나고 싶어한다. #Person1#은 폴리 씨에게 탄산 음료를 사달라고 요청하지만, #Person1#의 상사가 그 가게에 있다. 폴리 씨는 직접 가려고 한다.', '모니카는 재무 보고서를 읽을 시간을 찾고 있다. 프란시스는 금요일 오후에 모니카와 만날 수 있다.', '#Person2#는 #Person1#에게 면접 수업에 오신 것을 환영한다. #Person2#는 #Person1#에게 면접에 대해 이야기하고, #Person1#에게 면접에서 무엇을 해야 할지에 대한 추가적인 팁을 제공한다.', '#Person1#은 #Person2#에게 캐릭터가 분노와 슬픔을 동시에 느끼는 것이 아닐 수 있다고 말합니다. #Person2#는 그것을 시도해 보고 여전히 맞지 않는다면 다른 방법을 시도할 수 있습니다.', '#Person1#은 토드 부인의 정원을 방문하고 싶어한다. 토드 부인은 #Person1#에게 반갑다고 말한다.', '빌은 피곤해서 일찍 퇴근할 것입니다. 빌의 동생은 미국에 출장을 갔습니다. 빌의 시계는 4시 30분이라고 표시되어 있습니다.', '사이먼은 핵무기 확산을 막기 위한 시위에 갈 것이지만, 클레오는 시위에 가고 싶지 않다. 사이먼은 시위가 평화로울 것이라고 주장하지만, 클레오는 시험 공부할 계획이다.', '#Person1#은 #Person2#가 예상하지 못한 사람을 들여보내지 않는 것을 권장합니다.', '마크는 매기의 노트를 빌리려고 하지만, 매기는 그것을 복사하라고 제안한다. 마크는 수업 중에 자는 것을 걱정하고 매기는 그에게 깨워줄 수업 파트너가 될 수 있다고 제안한다.', '#Person2#는 고급 지질학 과목을 다시 듣고 싶어합니다. 터너 교수님은 #Person2#의 학력과 과목의 난이도에 대해 묻습니다. #Person2#는 #Person2#가 준비가 되었다고 생각합니다.', '#Person1#은 펜던트가 부러져서 새 것으로 교체하려고 합니다. #Perso ...

# %%
data = {
    'fname': fname_list,
    'summary': summary_list,
}

df = pd.DataFrame(data)
df
# Out:
#         fname                                            summary
# 0      test_0  #Person1#은 더슨 씨에게 내부 메모를 받아쓰도록 요청합니다. 더슨 씨는 메모...
# 1      test_1  #Person2#는 교통 체증에 걸려서 늦었다. #Person1#는 #Person2...
# 2      test_2  #Person1#은 케이트에게 마샤와 히어로가 이혼하려고 한다고 말한다. 케이트는 ...
# 3      test_3  #Person1#은 브라이언의 생일을 축하하고, 브라이언은 #Person1#에게 춤...
# 4      test_4  #Person2#는 #Person1#에게 올림픽 공원의 중심인 올림픽 스타디움에 대...
# ..        ...                                                ...
# 494  test_495  잭은 학교 끝나고 자신을 만드는 게임을 하기 위해 찰리를 집에 초대한다. 찰리는 흥...
# 495  test_496  #Person2#는 컨트리 음악에 관심을 가졌고, #Person2#는 라디오 방송국...
# 496  test_497  #Person1#은 세탁기 사용법을 알고 싶어합니다. 앨리스는 #Person1#에게...
# 497  test_498  스티브는 매튜에게 최근에 살 곳을 찾고 있다고 말한다. 매튜는 스티브에게 다우 부인...
# 498  test_499  프랭크는 승진했으므로 큰 파티를 열려고 한다. 벳시는 재미있을 것 같아서 파티에 갈...
#
# [499 rows x 2 columns]

# %%
df.to_csv('../../prediction/output.csv', encoding='utf-8-sig', index=False)
