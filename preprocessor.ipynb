# %% [markdown]
# ### 문자열의 앞뒤에서 공백 문자(스페이스, 탭, 줄바꿈 등)를 제거

# %%
import pandas as pd

def strip_all_columns(df):
    """
    데이터프레임의 모든 열에 대해 strip 처리를 수행합니다.
    문자열의 앞뒤에서 공백 문자(스페이스, 탭, 줄바꿈 등)를 제거합니다.
    """
    for column in df.columns:
        if df[column].dtype == 'object':  # 문자열 데이터인 경우에만 적용
            df[column] = df[column].str.strip()
    return df

train_df = pd.read_csv('./data/train.csv')
train_df = strip_all_columns(train_df)

# %% [markdown]
# ### Illegal characters 수정

# %%
import re

def fix_illegal_characters(text):
    """
    주어진 텍스트에서 특정 Illegal characters를 수정하고 연속된 공백을 하나로 바꿉니다.
    """
    if pd.isna(text):
        return text, []

    original_text = text
    fixed_chars = []

    # 1. '\u200b' (제로 너비 공백) 제거
    if '\u200b' in text:
        text = text.replace('\u200b', '')
        fixed_chars.append('\u200b')

    # 2. '\r' (캐리지 리턴) 을 '\n' (새 줄)으로 대체
    if '\r' in text:
        text = text.replace('\r', '\n')
        fixed_chars.append('\r')

    # 3. '\x08' (백스페이스) 제거
    if '\x08' in text:
        text = text.replace('\x08', '')
        fixed_chars.append('\x08')

    # 4. '\x1d' (그룹 분리자) 제거
    if '\x1d' in text:
        text = text.replace('\x1d', '')
        fixed_chars.append('\x1d')

    # 5. 연속된 새 줄 문자를 하나의 새 줄 문자로 대체
    text = re.sub(r'\n+', '\n', text)
    fixed_chars.append('\n+')

    # 6. 연속된 공백을 하나의 공백으로 대체
    if re.search(r' {2,}', text):
        text = re.sub(r' +', ' ', text)
        fixed_chars.append('multiple_spaces')

    # 수정된 문자가 있는 경우에만 변경된 것으로 간주
    if original_text != text:
        return text, list(set(fixed_chars))
    else:
        return text, []

def process_csv(df):
    """
    Illegal characters를 수정합니다.
    """
    if 'dialogue' not in df.columns:
        print("Error: 'dialogue' 열이 CSV 파일에 없습니다.")
        return

    total_fixes = 0
    fix_counts = {}

    def fix_and_count(text):
        nonlocal total_fixes
        fixed_text, fixed_chars = fix_illegal_characters(text)
        total_fixes += len(fixed_chars)
        for char in fixed_chars:
            fix_counts[char] = fix_counts.get(char, 0) + 1
        return fixed_text

    df['dialogue'] = df['dialogue'].apply(fix_and_count)
    df['summary'] = df['summary'].apply(fix_and_count)

    print(f"총 {total_fixes}개의 Illegal characters 또는 패턴이 수정되었습니다.")
    print("문자 또는 패턴별 수정 횟수:")
    for char, count in fix_counts.items():
        if char == 'multiple_spaces':
            print(f"  연속된 공백: {count}회")
        else:
            print(f"  {repr(char)}: {count}회")

    return df

train_df = process_csv(train_df)
# Out:
# 총 2540개의 Illegal characters 또는 패턴이 수정되었습니다.
# 문자 또는 패턴별 수정 횟수:
#   연속된 공백: 121회
#   '\n+': 1270회
#   '\u200b': 2회
#   '\r': 1134회
#   '\x08': 11회
#   '\x1d': 2회

# %% [markdown]
# ### 한글 모음/자음 처리

# %%
import pandas as pd
import re
from collections import Counter

def find_korean_jamo(text):
    """
    주어진 텍스트에서 한글 자음이나 모음을 찾아 반환합니다.
    
    :param text: 확인할 텍스트
    :return: 찾은 한글 자음/모음 리스트
    """
    # 한글 자음 모음 패턴
    jamo_pattern = re.compile('[ㄱ-ㅎㅏ-ㅣ]')
    return jamo_pattern.findall(text)

def check_korean_jamo_in_csv(df):
    """
    CSV 파일의 dialogue 열에서 한글 자음이나 모음이 포함된 대화를 찾습니다.
    
    :param file_path: CSV 파일 경로
    """
    if 'dialogue' not in df.columns:
        print("Error: 'dialogue' 열이 CSV 파일에 없습니다.")
        return
    
    # 한글 자음/모음이 포함된 대화 찾기
    all_jamo = []
    jamo_dialogues = []
    
    for _, row in df.iterrows():
        jamo = find_korean_jamo(row['dialogue'])
        if jamo:
            all_jamo.extend(jamo)
            jamo_dialogues.append((_, row['dialogue']))
    
    # 결과 출력
    print(f"총 대화 수: {len(df)}")
    print(f"한글 자음/모음이 포함된 대화 수: {len(jamo_dialogues)}")
    
    # 자음/모음 빈도 계산 및 출력
    jamo_freq = Counter(all_jamo)
    print("\n포함된 한글 자음/모음 목록 (빈도순):")
    for jamo, count in jamo_freq.most_common():
        print(f"{jamo}: {count}회")
    
    if jamo_dialogues:
        print("\n한글 자음/모음이 포함된 대화 예시 :")
        for idx, dialogue in jamo_dialogues:
            print(f"Index {idx}:")
            print(dialogue)
            print("포함된 자음/모음:", ", ".join(find_korean_jamo(dialogue)))
            print("-" * 50)

check_korean_jamo_in_csv(train_df)
check_korean_jamo_in_csv(pd.read_csv('./data/dev.csv'))
check_korean_jamo_in_csv(pd.read_csv('./data/test.csv'))
# Out:
# 총 대화 수: 12457
# 한글 자음/모음이 포함된 대화 수: 7
#
# 포함된 한글 자음/모음 목록 (빈도순):
# ㅋ: 4회
# ㅇ: 1회
# ㅣ: 1회
# ㅏ: 1회
# ㅍ: 1회
# ㄷ: 1회
#
# 한글 자음/모음이 포함된 대화 예시 :
# Index 3154:
# #Person1#: 짐! 잘 지내?
# #Person2#: 찰리! 저게 너의 차야? 완전 못생겼네, 친구야!
# #Person1#: 멍청이가 되지마! 이건 1969년형 쉐비 임팔라야! 좀 고쳐야겠지만. 몇 달 안에 이 아기는 완전 멋질 거야!
# #Person2#: 아니야! 이걸 봐! 이게 바로 멋진 차야!
# #Person1#: 아쉽게도 운전자는 완전 바보야. 그런 차를 가질 수 있는 건 아빠가 그만큼 돈이 많아서야.
# #Person2#: 그가 이쪽으로 오고 있어, 차분하게 있어.
# #Person3#: 여러분! 내 차 어때요? 완전 멋지지 않아요?
# #Person1#: 맞아! 여자들이 너를 그 차로 돌아다니는 걸 보면 너에게 줄을 서게 될 거야.
# #Person3#: 정말 그럴까요?
# #Person2#: 확실해!
# #Person3#: 대박!
# #Person1#: 속았어! ㅋㅋ.. 완전 속았어.
# #Person3#: 넌 진짜 나쁜 놈이야, 찰리. 프롬 퀸과 재미있는 시간을 보낼 때, 마지막 웃음은 누가 낼지 봐.
# #Person2#: 친구야, 화내지 마!
# 포함된 자음/모음: ㅋ, ㅋ
# --------------------------------------------------
# Index 5385:
# #Person1#: 제 영어 선생님이 저에게 오만과 편견을 읽으라고 하다니 믿을 수가 없어요!
# #Person2#: 왜요! 그건 클래식이에요. 사실, 제가 가장 좋아하는 소설 중 하나예요.
# #Person1#: 하지만 너무 오래됐어요.
# #Person2#: 표지만 보고 책을 판단하지 마세요. 그 내용을 알고 있나요?
# #Person1#: 아니요, 전혀 모르겠어요.
# #Person2#: 먼저, 이것은 19세기 초 배경ㅇ로 설정된 로맨스 소설이에요.
# #Person1#: 로맨스 소설인 줄 몰랐어요. 주요 스토리라인은 뭔가요?
# #Person2#: 아버지가 그의 다섯 딸 중 한 명을 결혼시키려고 노력하는 이야기에요.
# #Person1#: 그는 왜 그렇게 하려고 하나요?
# #Person2#: 그가 아들이 없기 때문에, 딸 중 한 명이 부유한 남자와 결혼하기를 바라는 거죠. 그렇게 하면 그의 모든 딸들이 잘 살 수 있을거니까요.
# #Person1#: 그들은 아버지의 상속을 받지 않나요?
# #Person2#: 아니요, 그게 문제죠. 그들은 부유하지만, 그가 죽으면 그의 집은 그의 사촌에게 갈 거예요. 그래서 그가 죽으면, 딸들은 아무것도 가지지 못할 거예요.
# #Person1#: 이해했어요. 이건 흥미롭네요! 아마 제 선생님이 그렇게 나쁘지 않은 건지도 몰라요.
# #Person2#: 그럼, 소설을 읽을 건지 영화를 볼 건지 결정했나요?
# #Person1#: 영화도 있어요? 제 선생님이 그런 건 말해주지 않았어요!
# #Person2#: 아마 그녀가 먼저 책을 읽게 하고 싶어서 그럴 거예요.
# #Person1#: 훨씬 덜 시간이 걸릴 텐데. . .
# #Person2#: 이렇게 어떨까요. 책을 다 읽으면, 저와 함께 영화를 보러 가요.
# #Person1#: 좋아요. 그럼 그렇게 하죠.
# 포함된 자음/모음: ㅇ
# --------------------------------------------------
# Index 5429:
# #Person1#: 너 남자친구 있어?
# #Person2#: 응, 전에 남자친구 있었어.
# #Person1#: 왜 전 남자친구야?
# #Person2#: 우리 지난달에 헤어졌어.
# #Person1#: 새로운 남자친구 생겼어?
# #Person2#: 음, 아니. 너는?
# #Person1#: 나는 혼자야, 실제 여자친구는 없고, 너처럼 E-여자친구만 있어.
# #Person2#: 하하, 그럼 나는 너의 E-남자친구야.
# #Person1#: 나 너 좋아해. 나의 여자친구가 되어줄래?
# #Person2#: 음... 그래, 한번 해보자.
# #Person1#: 와! 블라블라블라...
# #Person2#: 야! 그게 뭐야?
# #Person1#: 나는 마치 새처럼 날고 있어.
# #Person2#: ㅋㅋ
# #Person1#: 나 너무 행복해. 샴페인 한 잔 마시고 싶어.
# #Person2#: 지금 샴페인 없어. 이건 어때?
# #Person1#: 괜찮아, 그럼 이걸 너에게 보낼게.
# #Person2#: 이건 초콜릿으로 만든 거야?
# #Person1#: 이건 내 마음이야; 네가 좋아하는 걸로 만들어진 거야.
# #Person2#: 오, 달콤한 꿈 꾸겠네.
# #Person1#: 졸려?
# #Person2#: 좀 있어. 원치 않지만 잠들어야 해.
# #Person1#: 응, 나도 네가 사무실에서 잠드는 건 보고 싶지 않아.
# #Person2#: 고마워. 일단 안녕. 키스스스스스.
# #Person1#: 또 봐, 자기야.
# 포함된 자음/모음: ㅋ, ㅋ
# --------------------------------------------------
# Index 6942:
# #Person1#: 여기가 제 사촌이 운영하는 코펠리니 가게예요.
# #Person2#: 'ㅣ'로 끝나는 이탈리아 이름 같네요.
# #Person1#: 솔직히 말해봐요. 당신 무솔리니를 생각하고 있죠.
# #Person2#: 아니요, 저는 예술 애호가라서 벨리니와 보티첼리를 더 생각하게 돼요!
# #Person1#: 아, 그렇죠. 이탈리아인들은 인체의 감각적인 형태를 사랑하죠.
# #Person2#: 우리 모두 그렇죠... 어! 당신 사촌이 선물용품을 팔아요?
# #Person1#: 네-모두 이탈리아에서 온 거예요. 성자들 아시죠? 그들은 로마 가톨릭에서 중요해요.
# 포함된 자음/모음: ㅣ
# --------------------------------------------------
# Index 7201:
# #Person1#: 뭔지 맞춰볼래요? 나 좋은 소식이 있어요!
# #Person2#: 무슨 일이야?
# #Person1#: 제가 이코노미스트에서 교정사로 일하고 있다는 거 알고 계시죠, 맞죠?
# #Person2#: 응.
# #Person1#: 편집장이 제ㅏ 다른 잡지에서 편집자로 일했던 경험이 있다는 걸 듣고, 그가 도우미 편집자가 되고 싶냐고 물어봤어요.
# #Person2#: 정말이야? 그거 정말 대단한 일이네! 글 쓰는 기회도 있을까?
# #Person1#: 그녀가 문학 비평 칼럼의 칼럼니스트가 곧 출산 휴가를 가질 예정이라고 하고, 그녀가 돌아올 때까지 그 칼럼을 맡을 수 있을 것이라고 말했답니다.
# #Person2#: 와! 정말 좋은 소식이네. 그 잡지는 얼마나 자주 발행되는거야?
# #Person1#: 월간 잡지인데, 제 칼럼은 다른 칼럼니스트와 공유되기 때문에 제 기사는 격주로 내야 해요.
# #Person2#: 편집 작업을 더 많이 하게 되서 기대돼?
# #Person1#: 그렇긴 한데, 제 생각이 발행된다는 게 더욱 흥분되요!
# #Person2#: 여기에 잡지 구독을 신청할 수 있는 양식이 있니?
# #Person1#: 지금 가지고 있는 건 없는데, 아마 무료 복사본을 가져올 수 있을 것 같아요.
# #Person2#: 네 칼럼을 읽는 거 정말 기대된다.
# #Person1#: 저도 그래요. 좋은 소식을 축하하기 위해 밖에 나가볼래요?
# #Person2#: 그럼, 어디로 가고 싶어?
# #Person1#: 아마도 동네 서점에서 열리는 도서관 축제에 갈 수 있을 것 같아요.
# 포함된 자음/모음: ㅏ
# --------------------------------------------------
# Index 9677:
# #Person1#: 너 대신 퇴근 카드 찍어줄까, 로스? 난 이제 갈거야.
# #Person2#: 아니, 괜찮아. 나는 야근해야 해.
# #Person1#: 하지만 오늘은 금요일이잖아. 금요일 저녁에 야근하려고 하지는 않겠지?
# #Person2#: 음, 그래. 다음 주 월요일 회의를 위한 이 보고서를 끝내야 해. 톰이 널 데리러 오는 거야?
# #Person1#: 아니. 우리 집에서 만날 거야. 그가 우리 가족을 그의 별장에서 주말을 보내도록 초대했어.
# #Person2#: 좋네. 그의 별장은 어디에 있어?
# #Person1#: 그 별장은 그의 것이 아니라 그의 아버지의 것이야. 플로리다 어딘가인 것 같아. 나도 확실하지 않아.
# #Person2#: 가끔 너를 많이 부러워해. 톰은 좋은 사람이야.
# #Person1#: 이제 그만. 너는 아직ㅍ알맞는 사람을 만나지 못했을 뿐이고, 너는 너무 많이 일하는 것 같아. 너는 어떻게 즐기고 삶을 즐기는 법을 배워야 해.
# #Person2#: 알아, 하지만 나는 일광욕 중독자야.
# #Person1#: 그래, 네 맘대로 해. 나는 이제 가야 해.
# #Person2#: 좋은 주말 보내.
# #Person1#: 너도. 아, 한 가지 말을 잊었어. 오늘 오후에 한 여자가 전화했어. 그녀가 너의 전 여자친구라고 했어. 그녀가 너에게 전화하라고 했어.
# #Person2#: 그녀가 다른 얘기는 안했니?
# #Person1#: 아니, 다른 건 없었어. 월요일에 봐.
# #Person2#: 봐.
# 포함된 자음/모음: ㅍ
# --------------------------------------------------
# Index 12178:
# #Person1#: 도리스, 집에 와서 다행이야. 나 너무 무서워. 어떻게 해야 할지 모르겠어!
# #Person2#: 무슨 일이야? 무슨 일 있었어?
# #Person1#: 나를 따라다니는 사람이 있는 것 같아.
# #Person2#: 아니, 그럴리가. 정말이야? 누구?
# #Person1#: 모르겠어. 처음에는 화요일에 카페에서 그를 봤어. 그가 나를 자주 쳐다보는 걸 눈치챘어. 그냥 평범하게 보는 게 아니라 뚫어져라 쳐다봐. 그냥 계속 나를 쳐다봤어. 멈추지 않았어.
# #Person2#: 그럼 너는 어떻게 했어?
# #Person1#: 아무것도 안 했어. 그는 결국 나갔어. 그런데 오늘 또 그를 봤어. 신발 가게 밖에서. 카페 근처에서. 나는 CD 가게에 들어가서 CD를 보는 척했ㄷ거든. 그런데 그도 들어왔어.
# #Person2#: 너가 나갈 때 그도 나갔어?
# #Person1#: 응. 그런 다음에 그가 내 뒤에 있는 걸 발견했어. 그가 나를 따라오고 있었어.
# #Person2#: 그럼 너는 어떻게 했어?
# #Person1#: 그가 나를 집까지 따라왔어!
# #Person2#: 그게 대략 5블록이야. 그리고 모퉁이도 돌았어. 그러니까 그가 분명히 너를 따라왔어.
# #Person1#: 그래, 그랬어. 나 상상하는 게 아니야. 마침내 집에 도착했을 때, 나는 돌아서서 그를 봤어. 그는 그냥 서 있었어. 웃지도 않았어. 그냥 서 있었어. 정말 확실해. 어떻게 해야 할까? 너무 무서워. 경찰에 전화해도 될까?
# #Person2#: 사실, 아직은 경찰에 전화할 수 없을 것 같아. 아직까지는 그가 뭔가 한 건 아니니까. 그리고 아마 경찰은 그냥 무시할 거야. 그런데 또 무슨 일이 생기면 전화를 해야 할지도 몰라.
# #Person1#: 왜 지금 경찰에 전화할 수 없는 거야? 그가 분명히 나를 따라왔잖아!
# #Person2#: 당연히 너가 원한다면 경찰에 전화할 수 있어. 그게 아니라, 그들이 아마 아무것도 안 할 거라는 거야.
# #Person1#: 그럴 수도 있겠어. 그들이 뭘 할 수 있겠어? 나조차 그가 누군지 모르는데.
# #Person2#: 들어봐, 캐롤. 이 일로 너무 걱정하지 마. 아마 아무것도 아닐 거야. 밖에 나갈 때는 눈을 크게 뜨고 있어. 그를 세 번 더 보게 된다면, 그리고 그가 다시 너를 따라온다면, 그때는 경찰에 가야 할 것 같아. 그런데 지금은 걱정하지 마.
# #Person1#: 알았어. 그리고 나는 한동안 그 카페에 가지 않을 거야.
# 포함된 자음/모음: ㄷ
# --------------------------------------------------
# 총 대화 수: 499
# 한글 자음/모음이 포함된 대화 수: 0
#
# 포함된 한글 자음/모음 목록 (빈도순):
# 총 대화 수: 499
# 한글 자음/모음이 포함된 대화 수: 0
#
# 포함된 한글 자음/모음 목록 (빈도순):

# %%
train_df.at[3154, 'dialogue'] = train_df.at[3154, 'dialogue'].replace('ㅋㅋ', '하하')
train_df.at[5385, 'dialogue'] = train_df.at[5385, 'dialogue'].replace('ㅇ', '으')
train_df.at[5429, 'dialogue'] = train_df.at[5429, 'dialogue'].replace('ㅋㅋ', '하하')
train_df.at[7201, 'dialogue'] = train_df.at[7201, 'dialogue'].replace('ㅏ', '가')
train_df.at[9677, 'dialogue'] = train_df.at[9677, 'dialogue'].replace('ㅍ', ' ')
train_df.at[12178, 'dialogue'] = train_df.at[12178, 'dialogue'].replace('ㄷ', '')

# %%
check_korean_jamo_in_csv(train_df)
# Out:
# 총 대화 수: 12457
# 한글 자음/모음이 포함된 대화 수: 1
#
# 포함된 한글 자음/모음 목록 (빈도순):
# ㅣ: 1회
#
# 한글 자음/모음이 포함된 대화 예시 :
# Index 6942:
# #Person1#: 여기가 제 사촌이 운영하는 코펠리니 가게예요.
# #Person2#: 'ㅣ'로 끝나는 이탈리아 이름 같네요.
# #Person1#: 솔직히 말해봐요. 당신 무솔리니를 생각하고 있죠.
# #Person2#: 아니요, 저는 예술 애호가라서 벨리니와 보티첼리를 더 생각하게 돼요!
# #Person1#: 아, 그렇죠. 이탈리아인들은 인체의 감각적인 형태를 사랑하죠.
# #Person2#: 우리 모두 그렇죠... 어! 당신 사촌이 선물용품을 팔아요?
# #Person1#: 네-모두 이탈리아에서 온 거예요. 성자들 아시죠? 그들은 로마 가톨릭에서 중요해요.
# 포함된 자음/모음: ㅣ
# --------------------------------------------------

# %% [markdown]
# ### Dialogue 패턴 오류 수정

# %% [markdown]
# ##### Dialogue 패턴 분석

# %%
from collections import Counter

def check_dialogue_pattern(dialogue):
    """
    대화 패턴을 확인하고 예외를 찾습니다.
    발화자는 #PersonN# 형식을 따릅니다 (N은 숫자).
    """
    if pd.isna(dialogue):
        return False, "대화가 비어 있습니다."
    
    lines = dialogue.split('\n')
    speakers = []
    for i, line in enumerate(lines, 1):
        # 빈 줄 무시
        if not line.strip():
            continue
        
        # 패턴 확인
        match = re.match(r'^(#Person\d+#): (.+)', line)
        if not match:
            return False, f"{i}번째 줄이 올바른 형식이 아닙니다: {line}"
        
        speaker, content = match.groups()
        speakers.append(speaker)
        
        # 발화 내용이 비어있는지 확인
        if not content.strip():
            return False, f"{i}번째 줄의 대화 내용이 비어 있습니다: {line}"
    
    # 발화자 순서 확인
    if len(speakers) < 2:
        return False, "대화에 최소 두 명의 발화자가 필요합니다."
    
    # for i in range(1, len(speakers)):
    #     if speakers[i] == speakers[i-1]:
    #         return False, f"{i+1}번째 발화자가 이전 발화자와 같습니다: {speakers[i]}"
    
    # # 발화자 번호의 연속성 확인
    # speaker_numbers = sorted(set(int(re.search(r'\d+', s).group()) for s in speakers))
    # if speaker_numbers != list(range(min(speaker_numbers), max(speaker_numbers) + 1)):
    #     return False, f"발화자 번호가 연속적이지 않습니다: {speakers}"
    
    return True, "올바른 대화 패턴입니다."

def analyze_dialogue_patterns(df, column='dialogue'):
    """
    데이터프레임의 대화 열을 분석하고 패턴 예외를 찾습니다.
    결과를 CSV 파일로 저장합니다.
    """
    df = df.copy()
    
    results = df[column].apply(check_dialogue_pattern)
    df['is_valid_pattern'] = results.apply(lambda x: x[0])
    df['pattern_error'] = results.apply(lambda x: x[1])
    
    exceptions = df[~df['is_valid_pattern']]
    
    print(f"\n대화 패턴 분석 결과 ({column} 열):")
    print(f"전체 대화 수: {len(df)}")
    print(f"패턴 예외 수: {len(exceptions)}")
    
    if not exceptions.empty:
        print("\n패턴 예외 예시 (최대 5개):")
        for idx, row in exceptions.head().iterrows():
            print(f"\nIndex {idx}:")
            print(f"대화:\n{row[column]}")
            print(f"오류: {row['pattern_error']}")
    
    # 발화자 통계
    all_speakers = [speaker for dialogue in df[column].dropna() for speaker in re.findall(r'#Person\d+#', dialogue)]
    speaker_counts = Counter(all_speakers)
    
    print("\n발화자 통계:")
    print(f"유니크한 발화자 수: {len(speaker_counts)}")
    print("가장 흔한 발화자 Top :")
    for speaker, count in speaker_counts.most_common():
        print(f"{speaker}: {count}회")
    
    return exceptions

def analyze_dialogue_pattern(df):
    # 대화 패턴 분석
    dialogue_exceptions = analyze_dialogue_patterns(df)
    dialogue_exceptions
    return dialogue_exceptions

print("Train 대화 패턴 분석:")
dialogue_exceptions = analyze_dialogue_pattern(train_df)
dialogue_exceptions.to_csv(f'./data/dialogue_exceptions.csv', index=False)
print("\nDev 대화 패턴 분석:")
analyze_dialogue_pattern(pd.read_csv('./data/dev.csv'))
print("\nTest 대화 패턴 분석:")
analyze_dialogue_pattern(pd.read_csv('./data/test.csv'))
# Out:
# Train 대화 패턴 분석:
#
# 대화 패턴 분석 결과 (dialogue 열):
# 전체 대화 수: 12457
# 패턴 예외 수: 55
#
# 패턴 예외 예시 (최대 5개):
#
# Index 767:
# 대화:
# #Person1#: 저의 명함이 곧 다 떨어질 것 같아요. 새로운 것이 필요해요.
# #Person2#: 원하는 만큼 인쇄할 수 있어요. 몇 장이 필요한지만 말씀해주세요.
# #Person1#: 이천 장이면 올해를 보낼 수 있을 것 같아요.
# #Person2#: 시작하실 수 있도록 양식을 드릴게요.
# #Person1#: 제 이전 명함이 완벽해서, 그냥 그대로 복사해주기만 하면 돼요.
# #Person2#: 우리가 당신의 이전 명함을 얼마나 잘 복제하는지에 대해 매우 만족하실 거예요.
# #Person1#: . . . 여기 있어요
# #Person2#: 감사합니다. 다음 주 수요일에 주문하신 걸 찾으러 오세요.
# #Person1#: 죄송하지만, 3일 안에 만들어 줄 수 있을까요?
# #Person2#: 조금 더 비용을 지불하는 것이 괜찮다면, 전혀 문제 없습니다.
# #Person3#:
# 오류: 11번째 줄이 올바른 형식이 아닙니다: #Person3#:
#
# Index 839:
# 대화:
# #Person1#: 안녕하세요, 저희 은행에 오신 것을 환영합니다. 오늘은 무엇을 도와드릴까요?
# #Person2#: 정기예금에 대해 조언이 필요합니다.
# #Person1#: 무슨 문제가 있으신가요?
# #Person2#: 아니요, 문제 없습니다. 그냥 정기예금 중 하나가 만기가 되어서 어떻게 처리해야 할지 잘 모르겠어요.
# #Person1#: 그렇군요. 두 가지 선택이 있는데, 갱신하거나 교환할 수 있습니다. 어느 쪽을 선호하시나요?
# #Person2#: 음.. 지금까지 서비스에 만족하고 있으니 갱신하고 싶어요.
# #Person1#: 문제없습니다. 하지만 만기 시 계정 갱신이라는 새로운 서비스가 도입되었음을 알려드려도 될까요?
# #Person2#: 네. . .
# #사람1만기 시 계정 갱신 서비스는 만기일이 다가오면 자동으로 갱신되며, 고객님이 직접 이곳에 오셔서 정리하실 필요가 없다는 뜻입니다. 여기에 서명만 하시면 저희가 모든 것을 설정해 드립니다.
# #Person2#: 그게 저한테 딱 맞아요. 저는 센터에서 꽤 멀리 떨어져 살고 있어서 센터에 가는 것이 번거로울 때가 있거든요.
# 오류: 9번째 줄이 올바른 형식이 아닙니다: #사람1만기 시 계정 갱신 서비스는 만기일이 다가오면 자동으로 갱신되며, 고객님이 직접 이곳에 오셔서 정리하실 필요가 없다는 뜻입니다. 여기에 서명만 하시면 저희가 모든 것을 설정해 드립니다.
#
# Index 879:
# 대화:
# #Person1#: 아이들은 어떻게 운동하고 있나요?
# #Person2#: 아이들의 실력에 매우 만족합니다. 티미는 100미터를 12초 만에 주파할 수 있어요. 그 나이 또래 아이치고는 매우 빠른 속도입니다.
# #Person1#: 하지만 멀리뛰기는 잘 못하죠?
# #Person2#: 나쁘지 않아요. 4미터가 넘는 거리를 뛰어넘을 수 있어요. 그냥 점프보다 달리기를 더 좋아하는 것 같아요. 지미는 높이뛰기를 아주 잘해요. 2미터 이상도 뛰어넘을 수 있어요. 나이에 비해 괜찮은 실력이죠.
# #Person1#: 2미터요? 높이뛰기 바가 머리 위에 있다는 거네요! 장거리 달리기를 잘하는 아이가 있나요?
# #Person2#: 가장 오래 뛰는 경기는 1500미터예요. 남학생 몇 명과 여학생 한 명은 5분 안에 완주할 수 있어요.
# #Person1#: 수영은 잘하나요?
# #Person2#: 괜찮아요. 저는 아이들에게 매일 500미터를 수영하라고 해요. 수영장을 20바퀴 도는 거리죠. 아주 빠르지는 않지만 괜찮아요. 아이들이 힘을 키우고 몸매를 유지하길 바랄 뿐이에요.
# #Person1#: 케이트는 10미터 높이에서 다이빙을 아주 잘해요.
# #Person2#: 전 그 높이에서 뛰어내리는 게 무서워요!
# #Person1#:아직 두려움을 배우지 못한 것 같아요. 낮은 높이에서 다이빙을 시작했지만 곧 더 높은 곳으로 가고 싶어했어요.
# #Person2#: 더 빨리, 더 높이, 더 멀리 가는 것을 정말 즐기는 것 같아요.
# 오류: 11번째 줄이 올바른 형식이 아닙니다: #Person1#:아직 두려움을 배우지 못한 것 같아요. 낮은 높이에서 다이빙을 시작했지만 곧 더 높은 곳으로 가고 싶어했어요.
#
# Index 969:
# 대화:
# 제프, 이 광고를 봐! 아늑한 스튜디오 아파트를 월 700 달러에 임대한다고 되어 있어. 어때?
# #Person2#: 글쎄, 그 아파트는 제가 감당할 수 있을 것 같아. 하지만 애완동물은 허용돼?
# #Person1#: 음... 찾아볼게. 네, 애완동물을 허용하는 건물이라고 해.
# #Person2#: 좋네. 그럼 제 고양이, 트윙클 씨를 데려올 수 있겠어. 아파트는 어디에 있어?
# #Person1#: 교외에 위치해 있다고 써 있어.
# 오류: 1번째 줄이 올바른 형식이 아닙니다: 제프, 이 광고를 봐! 아늑한 스튜디오 아파트를 월 700 달러에 임대한다고 되어 있어. 어때?
#
# Index 1125:
# 대화:
# 사람1#: 제니, 이번 금요일에, 음... 바쁘세요?
# #Person2#: 네, 금요일에는 일 끝나고 바로 수업이 있어요.
# #Person1#: 그렇군요. 그럼 토요일은 어때요? 그날 시간 있으세요?
# #Person2#: 토요일에는 부모님이 오시려고 해요. 왜요?
# #Person1#: 그럼 오늘은요? 오늘은 다른 계획이 있으세요?
# #Person2#: 아니요. 뭔가 하려고 했어요?
# #Person1#: 네! 네! 저녁에 식사 대접하려고 했어요.
# #Person2#: 오! 좋아요! 여섯 시에 어떠세요?
# 오류: 1번째 줄이 올바른 형식이 아닙니다: 사람1#: 제니, 이번 금요일에, 음... 바쁘세요?
#
# 발화자 통계:
# 유니크한 발화자 수: 7
# 가장 흔한 발화자 Top :
# #Person1#: 61318회
# #Person2#: 56446회
# #Person3#: 384회
# #Person4#: 34회
# #Person6#: 6회
# #Person5#: 5회
# #Person7#: 2회
#
# Dev 대화 패턴 분석:
#
# 대화 패턴 분석 결과 (dialogue 열):
# 전체 대화 수: 499
# 패턴 예외 수: 2
#
# 패턴 예외 예시 (최대 5개):
#
# Index 48:
# 대화:
# #Person1#: 무엇을 도와드릴까요?
# #Person2#: 네, 다음 주 일요일 전에 출발하는 캐나다 캘거리행 항공편의 좌석 3석을 예약하고 싶습니다.
# #Person1#: 이코노미 클래스인가요?
# #Person2#: 네.
# #Person1#: 편도인가요, 왕복인가요?
# #Person2#: 편도입니다.
# #Person1#: 직항편이 없습니다. 밴쿠버에서 환승하셔야 합니다.
# #Person2#: 괜찮아요.
# #다음 주 금요일 오전 10시에 베이징에서 출발하는 캐나다항공 30편이 있습니다. 좌석이 3개 있습니다. 괜찮을까요?
# #Person2#: 네, 괜찮습니다.
# #Person1#: 성함을 말씀해 주세요.
# #Person2#: 바질, 바질입니다. 티켓이 얼마인가요?
# #Person1#: 한 장당 580달러입니다.
# 오류: 9번째 줄이 올바른 형식이 아닙니다: #다음 주 금요일 오전 10시에 베이징에서 출발하는 캐나다항공 30편이 있습니다. 좌석이 3개 있습니다. 괜찮을까요?
#
# Index 63:
# 대화:
# #Person1#: 좋아요, 이제 초기 입금에 대해 계속 이야기해 보겠습니다.
# #Person2#: 좋은 생각입니다. 얼마를 예치해야 하나요?
# #Person1#: 계약 저축의 경우 100, 000위안이 필요합니다.
# #Person2#: 필요한 경우 인출은 어떻게 하나요?
# #Person1#: 계약 저축 계좌는 결제 계좌와 동일하게 사용할 수 있습니다.
# #Person2#: 죄송합니다, 다시 생각해보겠습니다. B형 계좌는 어떻게 다른가요?
# #B형 계좌는 거래에 직접 관여할 수 없고 외부 출금 서비스도 이용할 수 없습니다.
# 오류: 7번째 줄이 올바른 형식이 아닙니다: #B형 계좌는 거래에 직접 관여할 수 없고 외부 출금 서비스도 이용할 수 없습니다.
#
# 발화자 통계:
# 유니크한 발화자 수: 4
# 가장 흔한 발화자 Top :
# #Person1#: 2428회
# #Person2#: 2242회
# #Person3#: 6회
# #Person4#: 1회
#
# Test 대화 패턴 분석:
#
# 대화 패턴 분석 결과 (dialogue 열):
# 전체 대화 수: 499
# 패턴 예외 수: 1
#
# 패턴 예외 예시 (최대 5개):
#
# Index 434:
# 대화:
# #Person1#: 헤이, 앤드류! 앤...? 앤드류.
# #Person2#: 뭐?
# #Person1#:앤드류.
# #Person2#: 뭐? 무슨 일이야?
# #Person1#: 너한테 무슨 일이 생겼어?
# #Person2#: 내 머리 말하는 거야? 내 머리가 마음에 드니?
# #Person1#: 음, 너도 내가 무슨 말하는지 알거라 생각해, 앤드류. 솔직하게 말해줄까?
# #Person2#: 뭐야?
# #Person1#:그래. 앤드류. 크리스마스 때 널 본 이후로 너, 많이 살이 찐 것 같아. 대체 무슨 일이 있었던 거야?
# #Person2#: 왜 넌 항상 그렇게 직설적이야?
# #Person1#: 그럼, 나는 너의 큰 누나니까. 내가... 내가 누구야? 너보다 세 살 많고, 원하면 직설적으로 말할 수 있어. 게다가, 너도 예전에 나한테 그런 말을 자주 했잖아. 내가 어렸을 때 항상 나를 뚱뚱이라고 불렀잖아.
# #Person2#: 오, 그래, 사실은, 음..., 나 어제부터 삶을 바꾸기 시작했어.
# #Person1#: 오, 좋아!
# #Person2#: 나 와푸 다이어트를 하고 있어.
# #Person1#: 뭐? 나는 와푸 다이어트라는 걸 들어본 적도 없어. 그게 뭔데?
# #Person2#: 아, 설명하기가 너무 어려워. 얼마 전에 스팸 메일에서 그 정보를 찾았어...
# #Person1#: 뭐? 너 스팸 메일 읽어? 아무도 스팸 메일을 안 읽어.
# #Person2#: ... 그리고 나는 그걸 가입했고, 그건 단지 $490밖에 안 했어.
# #Person1#: 진짜로?
# #Person2#: 응.
# #Person1#:  400달러와 90달러?
# #Person2#: 응.
# #Person1#: 매달이야 아니면 매주마다...?
# #Person2#: 그건 확인 안 했는데... 아, 아, 하지만... 나는...
# #Person1#: 들어봐. 나는 네가 사기를 당하고 있다고 생각하고, 그게 정말 바보 같아 보여. 들어봐. 나는 더 이상 뚱뚱하지 않아, 그러니 나를 믿어. 나... 네가 살을 빼고 싶다면, 제대로 해야 해.
# #Person2#: 그럼, 어떤 거?
# #Person1#: 음, 좋아.
# #Person2#: 좋아, 음, 봐. 저기 내 운동화를 봐.
# #Person1#: 앤드류. 그것들은 아직도 상자 안에 있어.
# #Person2#: 그럼 ...
# #Person1#: 한 번도 안 썼어. 운동 말고도, 응, 운동은 멋져. 정말 좋아, 하지만 너도 올바르게 먹는 법을 배워야 해. 예를 들어, 너는 더 적은 양을 먹어야 해. 그리고, 너는 항상 가족 파티에서 그랬던 것처럼 두 번째와 세 번째 접시를 가득 채우면 안 돼.
# #Person2#: 그럼, 좋아. 나는 그냥 더 큰 접시를 가져올게!
# #Person1#: 앤드류! 그건 도움이 안 돼. 다음으로
# #Person2#: 오, 다음?
# #Person1#: . 오, 그래. 그럼, 먼저, 적은 양
# #Person2#: 좋아.
# #Person1#: 그런 다음, 아침에 먼저 균형 잡힌 식사를 해야 해
# #Person2#: 나는 그렇게 해.
# #Person1#: 그리고 나서 하루 종일 적은 양의 식사를 계속 해, 왜냐하면, 알아? 아침 식사를 건너뛰면, 하루 종일, 점심과 저녁에 과식하고 많은 간식을 먹음으로써 보충해야 한다는 생각이 들어.
# #Person2#: 음 ...
# #Person1#: 어쨌든, 음, 오, 그래. 밤늦게 먹지 마.
# #Person2#:  뭐? 예를 들면?
# #Person1#:  그럼, 많은 사람들이 ... 그들은 ... 그들은 밤늦게 간식을 먹는 것 같은 것을 원하지만, 대부분의 경우, 그것은 정말로 고칼로리인 것들이고, 너의 몸이 그것을 태울만큼 활동적이지 않아서, 너는 그 모든 칼로리를 지방으로 저장해. 너는 버려야 해... 오 마이 갓!
# #Person2#:  뭐?
# #Person1#: 너의 냉동고에 있는 건 이것뿐이야! 너는 여기에 아이스크림밖에 없어! 이걸 다 버려야 해?
# #Person2#: 저칼로리 아이스크림이야.
# #Person1#: 저칼. 아니, 저칼로리가 아니야. 여기 봐. 앤드류! 여기에 있는 모든 음식은 아이스크림이야.
# #Person2#: 그럼, 또 뭐가 있을까? 그 밖에는?
# #Person1#: 또, 너는 그 밖에 뭘 먹고 있어?
# #Person2#: 음, 알다시피...
# #Person1#: 그러니까, 진짜. 너는 아이스크림밖에 안 먹어? 오, 오, 오. 너의 쓰레기통을 봐. 너는 매일 맥도날드에 가네. 매일 패스트푸드를 먹어?
# #Person2#: 음...
# #Person1#: 좋아, 너는 패스트푸드를 끊어야 해. 네가 맥도날드의 매니저를 이름으로 알고, 그가 너의 페이스북에서 최고의 친구라면, 너는 맥도날드나 어떤 패스트푸드점에 너무 자주 가는 거야.
# #Person2#: 음, 이건 힘들 것 같아.
# #Person1#: 응. 아마 그럴 거야. 하지만 너는 신선한 과일과 채소를 많이 먹어야 해.
# #Person2#: 오, 그래.
# #Person1#: 설탕을 훨씬 줄여. 네가 매일 마시는 그 설탕 든 음료 같은 건 더 이상 안 돼.
# #Person2#: 나는 5갤런을 마시지 않아.
# #Person1#: 충분히 비슷해. 그 컵의 크기를 봐! 몇 번이나 리필하니?
# #Person2#: 그럼, 그럼, 뭐 마시지?
# #Person1#: 물!
# #Person2#: 물?
# #Person1#: 그게 정말로 좋아.
# #Person2#: 오, 이건 힘들 것 같아.
# #Person1#: 그럴 수도 있어.
# 오류: 3번째 줄이 올바른 형식이 아닙니다: #Person1#:앤드류.
#
# 발화자 통계:
# 유니크한 발화자 수: 3
# 가장 흔한 발화자 Top :
# #Person1#: 2520회
# #Person2#: 2308회
# #Person3#: 15회
#         fname                                           dialogue  \
# 434  test_434  #Person1#: 헤이, 앤드류! 앤...? 앤드류.\n#Person2#: 뭐?\...
#
#      is_valid_pattern                        pattern_error
# 434             False  3번째 줄이 올바른 형식이 아닙니다: #Person1#:앤드류.

# %% [markdown]
# ##### 내용이 없는 줄을 제거

# %%
def remove_empty_dialogue_lines(dialogue):
    """
    대화에서 발화자만 있고 내용이 없는 줄을 제거합니다.

    :param dialogue: 원본 대화 문자열
    :return: 수정된 대화 문자열, 제거된 줄 수
    """
    lines = dialogue.strip().split('\n')
    filtered_lines = []
    removed_lines = 0

    for line in lines:
        # 발화자 태그와 내용 분리
        match = re.match(r'^(#[^#]+#:)\s*(.*)$', line.strip())
        if match:
            speaker, content = match.groups()
            if content.strip():  # 내용이 있는 경우만 포함
                filtered_lines.append(line.strip())
            else:
                removed_lines += 1
        else:
            filtered_lines.append(line.strip())  # 발화자 태그가 없는 줄은 그대로 유지

    return '\n'.join(filtered_lines), removed_lines

def delete_empty_line(df):
    """
    CSV 파일의 dialogue 열에서 빈 대화 줄을 제거합니다.
    """

    if 'dialogue' not in df.columns:
        print("Error: 'dialogue' 열이 CSV 파일에 없습니다.")
        return

    total_removed_lines = 0
    modified_dialogues = []

    def apply_removal(dialogue):
        nonlocal total_removed_lines
        cleaned_dialogue, removed = remove_empty_dialogue_lines(dialogue)
        total_removed_lines += removed
        if removed > 0:
            modified_dialogues.append((dialogue, cleaned_dialogue))
        return cleaned_dialogue

    df['dialogue'] = df['dialogue'].apply(apply_removal)

    print(f"\n총 {len(modified_dialogues)}개의 대화가 수정되었습니다.")

    for original, modified in modified_dialogues:
        print("\n원본 :")
        print(original)
        print("수정본 :")
        print(modified)
    
    return df

train_df = delete_empty_line(train_df)
# Out:
# 총 2개의 대화가 수정되었습니다.
#
# 원본 :
# #Person1#: 저의 명함이 곧 다 떨어질 것 같아요. 새로운 것이 필요해요.
# #Person2#: 원하는 만큼 인쇄할 수 있어요. 몇 장이 필요한지만 말씀해주세요.
# #Person1#: 이천 장이면 올해를 보낼 수 있을 것 같아요.
# #Person2#: 시작하실 수 있도록 양식을 드릴게요.
# #Person1#: 제 이전 명함이 완벽해서, 그냥 그대로 복사해주기만 하면 돼요.
# #Person2#: 우리가 당신의 이전 명함을 얼마나 잘 복제하는지에 대해 매우 만족하실 거예요.
# #Person1#: . . . 여기 있어요
# #Person2#: 감사합니다. 다음 주 수요일에 주문하신 걸 찾으러 오세요.
# #Person1#: 죄송하지만, 3일 안에 만들어 줄 수 있을까요?
# #Person2#: 조금 더 비용을 지불하는 것이 괜찮다면, 전혀 문제 없습니다.
# #Person3#:
# 수정본 :
# #Person1#: 저의 명함이 곧 다 떨어질 것 같아요. 새로운 것이 필요해요.
# #Person2#: 원하는 만큼 인쇄할 수 있어요. 몇 장이 필요한지만 말씀해주세요.
# #Person1#: 이천 장이면 올해를 보낼 수 있을 것 같아요.
# #Person2#: 시작하실 수 있도록 양식을 드릴게요.
# #Person1#: 제 이전 명함이 완벽해서, 그냥 그대로 복사해주기만 하면 돼요.
# #Person2#: 우리가 당신의 이전 명함을 얼마나 잘 복제하는지에 대해 매우 만족하실 거예요.
# #Person1#: . . . 여기 있어요
# #Person2#: 감사합니다. 다음 주 수요일에 주문하신 걸 찾으러 오세요.
# #Person1#: 죄송하지만, 3일 안에 만들어 줄 수 있을까요?
# #Person2#: 조금 더 비용을 지불하는 것이 괜찮다면, 전혀 문제 없습니다.
#
# 원본 :
# #Person1#: 안녕하세요, 저는 조지입니다. 오늘 저녁 담당 웨이터가 될게요. 주문하실 준비가 되셨나요, 아니면 조금 더 시간이 필요하신가요?
# #Person2#: 지금 주문할게요. 로스트 치킨과 옆으로 옥수수를 주세요.
# #Person1#: 그리고 식사 전에 애피타이저는 어떠신가요? 오늘의 수프는 맛있는 토마토 수프입니다.
# #Person2#: 수프는 패스하겠습니다만, 가든 샐러드는 주세요.
# #Person1#:
# #Person3#:
# #Person2#: 네, 아이스티 한 잔 주세요.
# #Person1#: 알겠습니다. 잠시 후에 음료와 샐러드를 가져다 드리겠습니다.
# #Person2#: 감사합니다.
# 수정본 :
# #Person1#: 안녕하세요, 저는 조지입니다. 오늘 저녁 담당 웨이터가 될게요. 주문하실 준비가 되셨나요, 아니면 조금 더 시간이 필요하신가요?
# #Person2#: 지금 주문할게요. 로스트 치킨과 옆으로 옥수수를 주세요.
# #Person1#: 그리고 식사 전에 애피타이저는 어떠신가요? 오늘의 수프는 맛있는 토마토 수프입니다.
# #Person2#: 수프는 패스하겠습니다만, 가든 샐러드는 주세요.
# #Person2#: 네, 아이스티 한 잔 주세요.
# #Person1#: 알겠습니다. 잠시 후에 음료와 샐러드를 가져다 드리겠습니다.
# #Person2#: 감사합니다.

# %% [markdown]
# ##### 발화자 패턴 수정

# %%
import random

def fix_dialogue_speakers(dialogue):
    """
    대화에서 발화자 태그를 수정합니다.
    1. ':' 를 기준으로 발화자와 내용을 구분합니다.
    2. 발화자 패턴이 '^(#Person\d+#): (.+)' 이 아닐 경우, 첫 번째 토큰을 다음 발화자 태그로 교체합니다.

    :param dialogue: 원본 대화 문자열
    :return: 수정된 대화 문자열, 수정 정보 딕셔너리
    """
    lines = dialogue.strip().split('\n')
    fixed_lines = []
    pattern = re.compile(r'^(#Person\d+#): (.+)')
    current_speaker = "#Person1#"
    modified = False

    for line in lines:
        match = pattern.match(line)
        if match:
            # 이미 올바른 패턴인 경우
            current_speaker = match.group(1)  # 패턴에서 발화자 추출
            fixed_lines.append(line)
        else:
            # 올바른 패턴이 아닌 경우
            parts = line.split(':', 1)
            if len(parts) == 2:
                _, content = parts
                content = content.strip()
            else:
                content = line.strip()
            
            fixed_line = f"{current_speaker}: {content}"
            fixed_lines.append(fixed_line)
            modified = True

        # 다음 발화자 준비
        current_speaker = f"#Person{2 if current_speaker == '#Person1#' else 1}#"

    fixed_dialogue = '\n'.join(fixed_lines)

    return fixed_dialogue, {"modified": modified}

def modify_dialogue_speakers(df):
    """
    CSV 파일의 dialogue 열에 fix_dialogue_speakers 함수를 적용하고,
    수정된 대화와 수정되지 않은 대화를 분리합니다.
    """

    if 'dialogue' not in df.columns:
        print("Error: 'dialogue' 열이 CSV 파일에 없습니다.")
        return

    modified_count = 0
    unmodified_count = 0
    modified_examples = []
    unmodified_examples = []

    def apply_fix(row):
        nonlocal modified_count, unmodified_count
        original_dialogue = row['dialogue']
        fixed_dialogue, info = fix_dialogue_speakers(original_dialogue)
        if info['modified']:
            modified_count += 1
            modified_examples.append((original_dialogue, fixed_dialogue))
            return fixed_dialogue
        else:
            unmodified_count += 1
            unmodified_examples.append(original_dialogue)
            return original_dialogue

    df['dialogue'] = df.apply(lambda row: apply_fix(row), axis=1)

    print(f"처리 완료:")
    print(f"수정된 대화 수: {modified_count}")
    print(f"수정되지 않은 대화 수: {unmodified_count}")

    # 수정된 대화 예시 출력
    print("\n수정된 대화 예시 (2개):")
    for original, fixed in random.sample(modified_examples, min(2, len(modified_examples))):
        print("원본:")
        print(original)
        print("\n수정됨:")
        print(fixed)
        print("-" * 50)

    # 수정되지 않은 대화 예시 출력
    print("\n수정되지 않은 대화 예시 (2개):")
    for original in random.sample(unmodified_examples, min(2, len(unmodified_examples))):
        print(original)
        print("-" * 50)

    return df

train_df = modify_dialogue_speakers(train_df)
# Out:
# 처리 완료:
# 수정된 대화 수: 53
# 수정되지 않은 대화 수: 12404
#
# 수정된 대화 예시 (2개):
# 원본:
# #Person1#: 방금 집어든 그 책은 뭔가요?
# #Person2#: 스미스 교수님이 수업에서 사용하는 사회학 교재에요.
# #Person1#: 그 과목을 통과하려면 그 책을 읽어야 할 거예요.
# #Person2#: 하지만 너무 비싸요. 제가 감당할 수 없어요.
# #Person1#: 얼마나 하나요?
# #Person2#: 40달러입니다.
# #Person1#: 여기 중고책 코너를 확인해 보셨나요? 아마 있을지도 몰라요.
# #Person2#: 없어요, 물어봤어요.
# #Person1#: 도서관에서 빌리면 어떨까요?
# #Person2#: 농담하시는 거죠? 몇 달 동안 시도해봤지만 항상 대출 중이에요. 이 과목에는 수강생이 45명이 넘는데 다들 책을 원해요.
# #Person1#: 들어봐요, 제 룸메이트인 헨리 알지요? 작년에도 같은 수업을 들었고, 저는 헨리가 그 책을 가지고 있다고 생각해요. 제가 그에게 빌려줄 수 있는지 물어볼게요.
# #Person2#:오, 톰, 그럼 모든 게 해결되겠네요. 정말 친절하시네요.
# #Person1#: 천만에요.
#
# 수정됨:
# #Person1#: 방금 집어든 그 책은 뭔가요?
# #Person2#: 스미스 교수님이 수업에서 사용하는 사회학 교재에요.
# #Person1#: 그 과목을 통과하려면 그 책을 읽어야 할 거예요.
# #Person2#: 하지만 너무 비싸요. 제가 감당할 수 없어요.
# #Person1#: 얼마나 하나요?
# #Person2#: 40달러입니다.
# #Person1#: 여기 중고책 코너를 확인해 보셨나요? 아마 있을지도 몰라요.
# #Person2#: 없어요, 물어봤어요.
# #Person1#: 도서관에서 빌리면 어떨까요?
# #Person2#: 농담하시는 거죠? 몇 달 동안 시도해봤지만 항상 대출 중이에요. 이 과목에는 수강생이 45명이 넘는데 다들 책을 원해요.
# #Person1#: 들어봐요, 제 룸메이트인 헨리 알지요? 작년에도 같은 수업을 들었고, 저는 헨리가 그 책을 가지고 있다고 생각해요. 제가 그에게 빌려줄 수 있는지 물어볼게요.
# #Person2#: 오, 톰, 그럼 모든 게 해결되겠네요. 정말 친절하시네요.
# #Person1#: 천만에요.
# --------------------------------------------------
# 원본:
# "#Person1#: 안녕하십니까, 예약하셨나요?
# #Person2#: 네. 왓슨 씨 이름으로 예약했습니다.
# #Person1#: 아, 네, 8시에 4인 테이블이요.
# #Person2#: 음, 네, 감사합니다. 바로 테이블로 가려고 합니다. 그런데, 여기에 제 코트를 맡길 수 있을까요?
# #Person1#: 물론이죠, 선생님. 물품함에 보관해 드리겠습니다. 여기 번호표입니다. 나가실 때 카운터 뒤에 계신 웨이터에게 보여주시면 됩니다.
# #Person2#: 감사합니다. 이제 저희 테이블로 안내해 주실 수 있나요?
# #Person1#: 저를 따라오시겠어요, 부탁드립니다.
# #Person2#: 감사합니다.
# #Person1#: 이곳이 귀하의 테이블입니다. 10번 테이블입니다.
#
# 수정됨:
# #Person1#: 안녕하십니까, 예약하셨나요?
# #Person2#: 네. 왓슨 씨 이름으로 예약했습니다.
# #Person1#: 아, 네, 8시에 4인 테이블이요.
# #Person2#: 음, 네, 감사합니다. 바로 테이블로 가려고 합니다. 그런데, 여기에 제 코트를 맡길 수 있을까요?
# #Person1#: 물론이죠, 선생님. 물품함에 보관해 드리겠습니다. 여기 번호표입니다. 나가실 때 카운터 뒤에 계신 웨이터에게 보여주시면 됩니다.
# #Person2#: 감사합니다. 이제 저희 테이블로 안내해 주실 수 있나요?
# #Person1#: 저를 따라오시겠어요, 부탁드립니다.
# #Person2#: 감사합니다.
# #Person1#: 이곳이 귀하의 테이블입니다. 10번 테이블입니다.
# --------------------------------------------------
#
# 수정되지 않은 대화 예시 (2개):
# #Person1#: 토플 시험 결과를 이미 받으셨나요?
# #Person2#: 네, 받았어요. 합격했어요!
# #Person1#: 축하드려요! 당신이 할 수 있을 거라고 알고 있었어요.
# #Person2#: 그런데, 당신의 도움 없이는 절대 할 수 없었을 거예요. 당신은 제가 만난 최고의 튜터였어요.
# #Person1#: 감사합니다, 하지만 그건 당신의 노력 덕분이었어요.
# #Person2#: 당신도 큰 공을 세웠어요. 당신으로부터 많이 배웠어요.
# --------------------------------------------------
# #Person1#: 무엇을 도와드릴까요?
# #Person2#: 머리를 자르고 싶어요.
# #Person1#: 알겠습니다. 이쪽으로 오세요.
# #Person2#: 정말 바빠 보이시네요.
# #Person1#: 일요일엔 특히나 바쁘지요. 여기 앉으세요. 어떻게 자르고 싶으신가요?
# #Person2#: 양쪽은 짧게 잘라 주시고, 중간은 그렇게 많이 자르지 않아도 돼요.
# #Person1#: 마지막으로 머리를 자른 지 오래되었네요, 그렇죠?
# #Person2#: 네. 맞아요.
# #Person1#: 얼마나 됐나요?
# #Person2#: 대략 두 달 정도 됐어요.
# --------------------------------------------------

# %% [markdown]
# ### 중복 된 dialogue, summary 확인

# %% [markdown]
# ##### dialogue, summary 모두 중복인 행 제거

# %%
def clear_duplicated(df):
    # 중복 확인
    print("중복 제거 전 데이터 개수:", len(df))
    duplicates = df[df.duplicated(subset=['dialogue', 'summary'], keep=False)]
    print("중복된 dialogue, summary 개수:", len(duplicates))

    # 중복 제거
    df.drop_duplicates(subset=['dialogue', 'summary'], inplace=True)
    print("중복 제거 후 데이터 개수:", len(df))

clear_duplicated(train_df)
# Out:
# 중복 제거 전 데이터 개수: 12457
# 중복된 dialogue, summary 개수: 4
# 중복 제거 후 데이터 개수: 12455

# %% [markdown]
# ##### 중복 summary 확인

# %%
# summary만 중복 확인
duplicates = train_df[train_df.duplicated(['summary'], keep=False)]
print("중복된 summary 개수:", len(duplicates))

duplicates = duplicates.sort_values(by='summary', ascending=True)
print(duplicates)
# Out:
# 중복된 summary 개수: 27
#              fname                                           dialogue  \
# 8785    train_8785  #Person1#: 음악 좋아해요?\n#Person2#: 그건 상황에 따라 다르죠....
# 8754    train_8754  #Person1#: 음악 좋아하시나요?\n#Person2#: 그건 상황에 따라 다르...
# 875      train_875  #Person1#: 안녕하세요, 파커. 어떻게 지내세요?\n#Person2#: 불만...
# 3654    train_3654  #Person1#: 안녕, 파커. 별일 없지?\n#Person2#: 그럭저럭 잘 지...
# 7550    train_7550  #Person1#: 왜 숙제를 안 하고 있니?\n#Person2#: 나중에 할게요,...
# 7551    train_7551  #Person1#: 좋아, 최신 지도를 가지고 있어. 여기서 공항까지의 경로를 확인...
# 1076    train_1076  #Person1#: 실례지만 잠시만 시간을 내 주실 수 있으세요?\n#Person2...
# 5673    train_5673  #Person1#: 실례합니다, 선생님. 잠시 시간을 내주실 수 있으신가요?\n#P...
# 8975    train_8975  #Person1#: 저는 기독교인이 아닙니다. 그런데 왜 미국인들이 그런 것을 믿는...
# 11608  train_11611  #Person1#: 저는 기독교인이 아닙니다. 그런데 왜 미국인들이 그런 것을 믿는...
# 6189    train_6189  #Person1#: 버스 패스는 얼마인가요?\n#Person2#: 월간 패스는 65...
# 6640    train_6640  #Person1#: 버스 패스는 얼마인가요?\n#Person2#: 월간 패스의 경우...
# 830      train_830  #Person1#: 내일이 제 첫 출근인데, 어떤 옷을 입는 게 좋을까요?\n#Pe...
# 831      train_831  #Person1#: 안녕, 빌. 너 졸업식에 갈 거야?\n#Person2#: 응. ...
# 2496    train_2496  #Person1#: 조금 있다 식료품 쇼핑을 갈 거예요.\n#Person2#: 왜요...
# 6135    train_6135  #Person1#: 조금 있다 식료품 쇼핑을 갈 거예요.\n#Person2#: 왜요...
# 7529    train_7529  #Person1#: 안녕하세요, 저는 다니엘입니다. 저는 매니저 직책에 지원하고 있...
# 7528    train_7528  #Person1#: 보고서 작성을 시작했나요?\n#Person2#: 정보를 얻는 데...
# 7527    train_7527  #Person1#: 나는 주변에서 가장 멋진 하이테크 스터드야. . .\n#Pers...
# 9947    train_9947  #Person1#: 잘 알려져 있듯이, 짐, 나는... 나는 대체적으로 너의 컴퓨터...
# 10095  train_10095  #Person1#: 잘 알려져 있듯이, 짐, 나는... 나는 컴퓨터를 꽤 좋아해. ...
# 2680    train_2680  #Person1#: 톰, 너 폐를 잘라야 한다고 약속했잖아. 잊지 않을거지?\n#P...
# 10360  train_10360  #Person1#: 톰, 너 폐를 잘라야 한다고 약속했잖아. 잊지 않을거지?\n#P...
# 7557    train_7557  #Person1#: 딩 씨, 안녕하세요? 저는 존 브라운입니다.\n#Person2#...
# 7556    train_7556  #Person1#: 쇼핑 가기 준비 됐어요?\n#Person2#: 조금만 기다려요....
# 9846    train_9846  #Person1#: 통통아, 숙제 다 했어? 우리 아빠를 역으로 만나러 가야 해.\...
# 11627  train_11630  #Person1#: 통통아, 숙제 다 했니? 아빠를 역에서 만나러 가야 해.\n#P...
#
#                                                  summary      topic
# 8785   #Person1#과 #Person2#는 노래에 대해 이야기합니다. 그들 모두 그것이...         음악
# 8754   #Person1#과 #Person2#는 노래에 대해 이야기합니다. 그들 모두 그것이...         음악
# 875                      #Person1#와 파커는 다음 수요일에 만날 예정이다.      만남 계획
# 3654                     #Person1#와 파커는 다음 수요일에 만날 예정이다.      일상 대화
# 7550   #Person1#은 #Person2#에게 숙제를 하라고 요청하지만, #Person2...    아빠와의 대화
# 7551   #Person1#은 #Person2#에게 숙제를 하라고 요청하지만, #Person2...      경로 확인
# 1076   #Person1#은 #Person2#에게 출퇴근 방식과 철도 서비스에 대한 의견을 ...     철도 서비스
# 5673   #Person1#은 #Person2#에게 출퇴근 방식과 철도 서비스에 대한 의견을 ...     철도 서비스
# 8975   #Person1#은 기독교인이 아니며 하나님을 믿는 이유를 알고 싶어합니다. 존은 ...  종교에 대한 토론
# 11608  #Person1#은 기독교인이 아니며 하나님을 믿는 이유를 알고 싶어합니다. 존은 ...         종교
# 6189   #Person1#은 버스 패스에 대해 #Person2#에게 몇 가지 질문을 하고, ...      버스 패스
# 6640   #Person1#은 버스 패스에 대해 #Person2#에게 몇 가지 질문을 하고, ...      버스 패스
# 830     #Person1#은 빌과 함께 졸업식에 참석한다. 그들은 졸업에 대한 감정을 표현한다.      복장 규정
# 831     #Person1#은 빌과 함께 졸업식에 참석한다. 그들은 졸업에 대한 감정을 표현한다.         졸업
# 2496   #Person1#은 식료품 쇼핑을 갈 예정이지만 무엇을 사야 할지 모른다. #Per...     식료품 쇼핑
# 6135   #Person1#은 식료품 쇼핑을 갈 예정이지만 무엇을 사야 할지 모른다. #Per...      쇼핑 가기
# 7529   #Person1#은 자신이 MP3 플레이어와 스테레오 헤드폰을 가지고 있기 때문에 ...      직업 면접
# 7528   #Person1#은 자신이 MP3 플레이어와 스테레오 헤드폰을 가지고 있기 때문에 ...      정보 얻기
# 7527   #Person1#은 자신이 MP3 플레이어와 스테레오 헤드폰을 가지고 있기 때문에 ...   하이테크 스터드
# 9947   #Person1#은 컴퓨터가 아이들에게 생각하는 법을 가르친다고 생각하는 반면, 짐...    컴퓨터의 영향
# 10095  #Person1#은 컴퓨터가 아이들에게 생각하는 법을 가르친다고 생각하는 반면, 짐...    컴퓨터의 영향
# 2680              #Person1#은 톰에게 여러 가지를 요청하며 그의 약속을 청한다.         약속
# 10360             #Person1#은 톰에게 여러 가지를 요청하며 그의 약속을 청한다.     약속 지키기
# 7557   #Person2#는 #Person1#와 함께 쇼핑을 갈 예정입니다. #Person2...     계약서 서명
# 7556   #Person2#는 #Person1#와 함께 쇼핑을 갈 예정입니다. #Person2...      쇼핑 가기
# 9846                  통통이 #Person1#에게 숙제를 곧 끝낼 것이라고 말한다.         숙제
# 11627                 통통이 #Person1#에게 숙제를 곧 끝낼 것이라고 말한다.         숙제

# %% [markdown]
# ##### 잘못 요약된 summary 삭제

# %%
values_to_delete = ['train_7551', 'train_830', 'train_7528', 'train_7529', 'train_7557'] 
train_df = train_df[~train_df['fname'].isin(values_to_delete)]

train_df
# Out:
#              fname                                           dialogue  \
# 0          train_0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1          train_1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2          train_2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3          train_3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4          train_4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
# ...            ...                                                ...
# 12452  train_12455  #Person1#: 실례합니다. 맨체스터 출신의 그린 씨이신가요?\n#Person2...
# 12453  train_12456  #Person1#: 이윙 씨가 우리가 컨퍼런스 센터에 오후 4시에 도착해야 한다고 ...
# 12454  train_12457  #Person1#: 오늘 어떻게 도와드릴까요?\n#Person2#: 차를 빌리고 싶...
# 12455  train_12458  #Person1#: 오늘 좀 행복해 보이지 않아. 무슨 일 있어?\n#Person2...
# 12456  train_12459  #Person1#: 엄마, 다음 토요일에 이 삼촌네 가족을 방문하기 위해 비행기를 ...
#
#                                                  summary     topic
# 0      스미스씨가 건강검진을 받고 있고, 호킨스 의사는 매년 건강검진을 받는 것을 권장합니...   건강검진 받기
# 1      파커 부인이 리키를 데리고 백신 접종을 하러 갔다. 피터스 박사는 기록을 확인한 후...        백신
# 2      #Person1#은 열쇠 한 묶음을 찾고 있고, 그것을 찾기 위해 #Person2#...     열쇠 찾기
# 3      #Person1#은 #Person2#가 여자친구가 있고 그녀와 결혼할 것이라는 사실...  여자친구가 있다
# 4      말릭이 니키에게 춤을 요청한다. 말릭이 발을 밟는 것을 신경 쓰지 않는다면 니키는 ...        댄스
# ...                                                  ...       ...
# 12452  탄 링은 흰머리와 수염으로 쉽게 인식되는 그린 씨를 만나 호텔로 데려갈 예정입니다....  누군가를 태우다
# 12453  #Person1#과 #Person2#는 이윙 씨가 늦지 않도록 요청했기 때문에 컨퍼...   컨퍼런스 센터
# 12454       #Person2#는 #Person1#의 도움으로 5일 동안 소형 차를 빌립니다.      차 렌트
# 12455  #Person2#의 엄마가 일자리를 잃었다. #Person2#는 엄마가 우울해하지 ...        실직
# 12456  #Person1#은 다음 토요일에 이 삼촌네를 방문할 때 가방을 어떻게 싸야 할지 ...      짐 싸기
#
# [12450 rows x 4 columns]

# %% [markdown]
# ##### 중복 dialogue 확인

# %%
# dialogue만 중복 확인
duplicates = train_df[train_df.duplicated(['dialogue'], keep=False)]
print("중복된 dialogue 개수:", len(duplicates))

duplicates = duplicates.sort_values(by='dialogue', ascending=True)
print(duplicates)
# Out:
# 중복된 dialogue 개수: 104
#              fname                                           dialogue  \
# 12418  train_12421  #Person1#: 그들은 우리에게 바다 전망을 약속했어요.\n#Person2#: ...
# 11536  train_11539  #Person1#: 그들은 우리에게 바다 전망을 약속했어요.\n#Person2#: ...
# 5942    train_5942  #Person1#: 그래서, 수잔, 이번 토요일에 계획이 있나요?\n#Person2...
# 6409    train_6409  #Person1#: 그래서, 수잔, 이번 토요일에 계획이 있나요?\n#Person2...
# 2131    train_2131  #Person1#: 근육을 스트레칭하고 건강해지는 데 도움이 되는 몇 가지 운동을 ...
# ...            ...                                                ...
# 7294    train_7294  #Person1#: 헤이, 빌. 새 프로젝트로 널 독일로 보낼 거라는 소식을 들었어...
# 4946    train_4946  #Person1#: 현지 유명 영매에 대한 이 신문 기사를 보세요. 기사에 따르면 ...
# 4834    train_4834  #Person1#: 현지 유명 영매에 대한 이 신문 기사를 보세요. 기사에 따르면 ...
# 8092    train_8092  #Person1#: 환영합니다!\n#Person2#: 맥주 한 병 주시겠어요?\n#...
# 5495    train_5495  #Person1#: 환영합니다!\n#Person2#: 맥주 한 병 주시겠어요?\n#...
#
#                                                  summary        topic
# 12418  #Person2#는 #Person1#이 끔찍한 장소에 대해 불평할 때 그들이 그냥 ...       끔찍한 장소
# 11536  #Person1#은 바다 전망에 대해 불평하고 #Person2#는 그들이 참아야 한...        바다 전망
# 5942   #Person1#은 수잔에게 이번 토요일에 만나자고 제안하지만, 수잔은 바쁘다. 수...        주말 계획
# 6409   #Person1#은 토요일에 영화를 보거나 산책을 하자고 한다. 그러나 수잔은 집 ...          바쁘다
# 2131   #Person2#는 #Person1#에게 #Person1#의 근육을 스트레칭하고 건...           운동
# ...                                                  ...          ...
# 7294   #Person1#은 빌이 새 프로젝트를 위해 독일로 간다는 소식을 듣습니다. #Pe...       새 프로젝트
# 4946   #Person1#과 #Person2#가 점쟁이에 대해 이야기하고 있습니다. #Per...          점쟁이
# 4834   신문에 영매에 대한 보도가 실렸습니다. #Person2#는 그런 것을 믿지 않습니다...  점쟁이에 대한 이야기
# 8092   #Person2#는 얼음 없는 맥주 한 병과 주스 한 잔을 #Person1#에게 요...        주문 받기
# 5495           #Person2#님이 #Person1#의 도움으로 맥주와 주스를 주문한다.        음료 주문
#
# [104 rows x 4 columns]

# %% [markdown]
# ##### 중복 dialogue의 summary 와의 유사도 확인

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from konlpy.tag import Okt
from tqdm import tqdm

def preprocess_korean_text(text):
    okt = Okt()
    tokens = okt.morphs(text)
    return ' '.join(tokens)

def keyword_matching(dialogue, summary):
    vectorizer = CountVectorizer()
    dialogue = preprocess_korean_text(dialogue)
    summary = preprocess_korean_text(summary)
    corpus = [dialogue, summary]
    vectors = vectorizer.fit_transform(corpus)
    keywords = vectorizer.get_feature_names_out()
    dialogue_vector = vectors[0].toarray()[0]
    summary_vector = vectors[1].toarray()[0]
    common_keywords = [word for word, count1, count2 in zip(keywords, dialogue_vector, summary_vector) if count1 > 0 and count2 > 0]
    return len(common_keywords) / len(keywords)

def sentence_similarity(dialogue, summary):
    model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
    dialogue_embedding = model.encode(dialogue)
    summary_embedding = model.encode(summary)
    similarity = cosine_similarity([dialogue_embedding], [summary_embedding])[0][0]
    return similarity

def calc(df):
    # 키워드 매칭과 문장 유사도 계산
    tqdm.pandas(desc="Keyword Matching")
    df['keyword_match_ratio'] = df.progress_apply(lambda x: keyword_matching(x['dialogue'], x['summary']), axis=1)
    # tqdm.pandas(desc="Sentence Similarity")  
    # df['sentence_similarity'] = df.progress_apply(lambda x: sentence_similarity(x['dialogue'], x['summary']), axis=1)
    
    return df
   
duplicates = calc(duplicates)
# Out:
# Keyword Matching: 100%|██████████| 104/104 [00:03<00:00, 28.98it/s]

# %%
duplicates = duplicates.sort_values(by=['keyword_match_ratio'], axis=0)
duplicates

duplicates.to_csv('./data/train_duped_dialogue.csv', index=False)

# %% [markdown]
# ##### 잘못 요약된 dialogue 삭제

# %%
values_to_delete = ['train_10066', 'train_10062'] 
train_df = train_df[~train_df['fname'].isin(values_to_delete)]
train_df
# Out:
#              fname                                           dialogue  \
# 0          train_0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1          train_1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2          train_2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3          train_3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4          train_4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
# ...            ...                                                ...
# 12452  train_12455  #Person1#: 실례합니다. 맨체스터 출신의 그린 씨이신가요?\n#Person2...
# 12453  train_12456  #Person1#: 이윙 씨가 우리가 컨퍼런스 센터에 오후 4시에 도착해야 한다고 ...
# 12454  train_12457  #Person1#: 오늘 어떻게 도와드릴까요?\n#Person2#: 차를 빌리고 싶...
# 12455  train_12458  #Person1#: 오늘 좀 행복해 보이지 않아. 무슨 일 있어?\n#Person2...
# 12456  train_12459  #Person1#: 엄마, 다음 토요일에 이 삼촌네 가족을 방문하기 위해 비행기를 ...
#
#                                                  summary     topic
# 0      스미스씨가 건강검진을 받고 있고, 호킨스 의사는 매년 건강검진을 받는 것을 권장합니...   건강검진 받기
# 1      파커 부인이 리키를 데리고 백신 접종을 하러 갔다. 피터스 박사는 기록을 확인한 후...        백신
# 2      #Person1#은 열쇠 한 묶음을 찾고 있고, 그것을 찾기 위해 #Person2#...     열쇠 찾기
# 3      #Person1#은 #Person2#가 여자친구가 있고 그녀와 결혼할 것이라는 사실...  여자친구가 있다
# 4      말릭이 니키에게 춤을 요청한다. 말릭이 발을 밟는 것을 신경 쓰지 않는다면 니키는 ...        댄스
# ...                                                  ...       ...
# 12452  탄 링은 흰머리와 수염으로 쉽게 인식되는 그린 씨를 만나 호텔로 데려갈 예정입니다....  누군가를 태우다
# 12453  #Person1#과 #Person2#는 이윙 씨가 늦지 않도록 요청했기 때문에 컨퍼...   컨퍼런스 센터
# 12454       #Person2#는 #Person1#의 도움으로 5일 동안 소형 차를 빌립니다.      차 렌트
# 12455  #Person2#의 엄마가 일자리를 잃었다. #Person2#는 엄마가 우울해하지 ...        실직
# 12456  #Person1#은 다음 토요일에 이 삼촌네를 방문할 때 가방을 어떻게 싸야 할지 ...      짐 싸기
#
# [12448 rows x 4 columns]

# %% [markdown]
# ##### 중복 외에도 잘못 요약된 것이 없는지 확인

# %%
import pandas as pd
import re
from konlpy.tag import Okt
from collections import Counter

okt = Okt()

def extract_person_names(text):
    """
    텍스트에서 '은', '는', '이', '가' 앞에 오는 단어 중 명사, 대명사, 고유명사를 추출합니다.
    
    :param text: 분석할 텍스트
    :return: 추출된 이름 리스트
    """
    # OKR의 형태소 분석 결과 얻기
    pos_tags = okt.pos(text)
    
    names = []
    specific_particles = ['은', '는', '이', '가']
    
    for i in range(len(pos_tags) - 1):
        word, tag = pos_tags[i]
        # print(i)
        # print(tag)
        # print(word)
        next_word, next_tag = pos_tags[i + 1]
        
        # 현재 단어가 명사이고 다음 단어가 특정 조사인 경우
        if tag in ['Noun'] and next_word in specific_particles:
            names.append(word)
    
    return names

def find_mismatched_names(df):
    """
    CSV 파일에서 summary의 이름이 dialogue에 없는 행을 찾습니다.
    
    :param input_file: 입력 CSV 파일 경로
    :return: 불일치하는 행들의 DataFrame, 불일치하는 이름들의 Counter
    """

    if 'dialogue' not in df.columns or 'summary' not in df.columns:
        print("Error: 'dialogue' 또는 'summary' 열이 CSV 파일에 없습니다.")
        return pd.DataFrame(), Counter()
    
    mismatched_rows = []
    all_mismatched_names = []
    
    for index, row in df.iterrows():
        summary_names = extract_person_names(row['summary'])
        
        mismatched_names = [name for name in summary_names if name not in row['dialogue']]
        
        if mismatched_names:
            mismatched_rows.append({
                'index': index,
                'summary': row['summary'],
                'dialogue': row['dialogue'],
                'mismatched_names': ', '.join(mismatched_names)
            })
            all_mismatched_names.extend(mismatched_names)
    
    result_df = pd.DataFrame(mismatched_rows)
    name_counts = Counter(all_mismatched_names)
    
    return result_df, name_counts

mismatched_df, name_counts = find_mismatched_names(train_df)

if not mismatched_df.empty:
    mismatched_df.to_csv('./data/train_mismatched.csv', index=False)
    print(f"불일치하는 {len(mismatched_df)}개의 행을 찾았습니다.")
    
    print("\n불일치하는 행의 예시 (최대 5개):")
    for _, row in mismatched_df.head().iterrows():
        print(f"Index: {row['index']}")
        print(f"Summary: {row['summary']}")
        print(f"Dialogue: {row['dialogue']}")
        print(f"불일치하는 이름: {row['mismatched_names']}")
        print("-" * 50)
    
    print("\n불일치하는 이름들의 등장 횟수 (적은 순):")
    for name, count in sorted(name_counts.items(), key=lambda x: x[1]):
        print(f"{name}: {count}회")
else:
    print("불일치하는 행을 찾지 못했습니다.")
# Out:
# 불일치하는 1555개의 행을 찾았습니다.
#
# 불일치하는 행의 예시 (최대 5개):
# Index: 7
# Summary: 주디 리아오는 회계 보조 자리에 지원하고 있습니다. 그녀는 #Person1#에게 이력서를 받았는지 물었고, #Person1#은 그녀에게 확인해주었습니다. #Person1#은 주디에게 다른 것을 보낼 필요가 없다고 말하고, 일주일이나 두 주 후에 지원자들에게 전화를 걸기 시작할 것이라고 말했습니다.
# Dialogue: #Person1#: 도와드릴 일이 있나요?
# #Person2#: 네. 저는 지난 주말에 이력서를 보냈습니다. 회계 보조 자리에 지원하려고 합니다.
# #Person1#: 이름을 알려주실 수 있나요?
# #Person2#: 제 이름은 주디 리아오입니다. 엘 아이 에이 오로 씁니다.
# #Person1#: 알겠습니다. . . 지원서에 대해 특별히 궁금한 점이 있나요?
# #Person2#: 아니요. 근처에 있어서 제 이력서를 받았는지 확인하러 들렸습니다.
# #Person1#: 아, 문제 없습니다. 잠시만 기다려주시면 확인해보겠습니다. 주디 리아오. 찾아보겠습니다. . . 네, 여기 있네요.주디 리아오. 이력서를 받았습니다.
# #Person2#: 감사합니다.
# #Person1#: 다른 도움이 필요한 것이 있나요?
# #Person2#: 네, 아마도요. 신문 광고에는 이력서, 자기소개서, 그리고 추천서 두 통을 원한다고 써 있었습니다. 그것들을 모두 봉투에 넣어 보냈습니다. 다른 것을 보내야 할까요?
# #Person1#: 아니요, 그것들만 있으면 충분합니다. 그것들이 포함되어 있다면 충분합니다.
# #Person2#: 면접 일정이 언제 시작되는지 아시나요?
# #Person1#: 그건 정확히 모르겠습니다. 하지만 아직도 이력서를 받고 있습니다. 아마 일주일이나 두 주 후에 지원자들에게 전화를 걸기 시작할 것 같습니다.
# #Person2#: 알겠습니다. 도와주셔서 정말 감사합니다. 많은 도움이 되었습니다.
# #Person1#: 추가적인 질문이 있으시면 언제든지 전화하실 수 있습니다.
# #Person2#: 감사합니다.
# #Person1#: 감사합니다. 안녕히 가세요.
# 불일치하는 이름: 그녀
# --------------------------------------------------
# Index: 8
# Summary: #Person1#은 기본 컴퓨터 패키지를 #Person2#에게 보여줍니다. #Person2#는 그것이 좋다고 생각하고 구매하려 합니다.
# Dialogue: #Person1#: 이것은 좋은 기본 컴퓨터 패키지입니다. 좋은 CPU, 256메가바이트의 RAM, 그리고 DVD 플레이어가 있습니다.
# #Person2#: 모뎀도 포함되어 있나요?
# #Person1#: 네, 내장 모뎀이 있습니다. 전화선을 컴퓨터 뒷면에 꽂기만 하면 됩니다.
# #Person2#: 모니터는 어떤가요?
# #Person1#: 15인치 모니터가 포함되어 있습니다. 원한다면 약간의 추가 비용으로 17인치 모니터로 바꿀 수 있습니다.
# #Person2#: 괜찮습니다. 15인치면 충분합니다. 좋습니다, 제가 사겠습니다.
# 불일치하는 이름: 그것
# --------------------------------------------------
# Index: 16
# Summary: #Person2#는 #Person1#에게 자신의 발렌타인 데이에 대해 이야기합니다. #Person1#는 그것이 로맨틱하다고 느낍니다.
# Dialogue: #Person1#: 발렌타인 데이에 대해 말해주세요.
# #Person2#: 그날에는 보통 남자들이 연인에게 장미를 선물하고, 여자들은 그들에게 초콜릿을 선물로 돌려줘요.
# #Person1#: 정말 로맨틱하네요. 젊은 사람들은 정말 재미있게 보내겠어요.
# #Person2#: 그렇죠, 그게 바로 그 휴일의 목적이지 않을까요?
# 불일치하는 이름: 그것
# --------------------------------------------------
# Index: 36
# Summary: 리사는 프로그램에 합격하여 내년에 일본에 갈 예정이다. 그녀는 #Person1#에게 외국어를 완벽하게 구사할 필요가 없는 프로그램에 참여하도록 권장한다.
# Dialogue: #Person1#: 리사야, 뭐 보고 있어?
# #Person2#: 일본 영화. 내년에 일년 동안 일본에 있을 예정이라서 그 문화에 대해 더 알아야겠어.
# #Person1#: 네 말은 프로그램에 합격했다는 거야?
# #Person2#: 물론이지.
# #Person1#: 대단하다. 기대되겠어.
# #Person2#: 기대되기도 하고 떨리기도 해. 내가 기본적인 대화 기술을 향상시켜야 한다는 거 알잖아.
# #Person1#: 일본어를 얼마나 이해할 수 있어?
# #Person2#: 지금은 조금밖에 못해. 하지만 다음 달에 특별한 언어 수업을 들을 예정이야.
# #Person1#: 나도 너처럼 외국어를 잘하면 좋겠어. 해외에서 공부하고 싶어.
# #Person2#: 그럼 왜 안해? 학교에는 외국어를 완벽하게 구사할 필요가 없는 프로그램이 많아. 단지 새로운 환경에 빠르게 적응할 수 있는 사람이면 돼.
# #Person1#: 모든 프로그램이 외국어를 알아야 한다고 생각했어. 이런 정보를 알려줘서 고마워.
# 불일치하는 이름: 그녀
# --------------------------------------------------
# Index: 42
# Summary: 짐이 스미스 박사님에게 전화를 거는데, 그는 없습니다. #Person2#가 짐에게 그의 번호를 물어봅니다.
# Dialogue: #Person1#: 안녕하세요, 이곳이 스미스 박사님의 사무실인가요?
# #Person2#: 네, 맞습니다. 무엇을 도와드릴까요?
# #Person1#: 네, 스미스 박사님과 통화하고 싶은데요?
# #Person2#: 스미스 박사님은 오후에 집으로 가셨습니다. 전화하신 분이 누구신지 여쭤봐도 될까요?
# #Person1#: 제 이름은 짐 화이트입니다.
# #Person2#: 아, 화이트 씨. 스미스 박사님께서 집 전화번호를 알려드리라고 하셨습니다.
# #Person1#: 잠시만요. 네, 그 번호가 어떻게 되나요?
# #Person2#: 그의 번호는 #PhoneNumber#입니다.
# #Person1#: 정말 감사합니다.
# #Person2#: 괜찮습니다.
# 불일치하는 이름: 거
# --------------------------------------------------
#
# 불일치하는 이름들의 등장 횟수 (적은 순):
# 사업: 1회
# 골프공: 1회
# 음식: 1회
# 약속: 1회
# 목적: 1회
# 다툼: 1회
# 루스: 1회
# 소리: 1회
# 맞춤: 1회
# 과: 1회
# 눈: 1회
# 혜택: 1회
# 여: 1회
# 웨이터: 1회
# 수단: 1회
# 비즈니스: 1회
# 개장: 1회
# 이씨: 1회
# 인형: 1회
# 형: 1회
# 불만: 1회
# 에너지: 1회
# 경관: 1회
# 바퀴: 1회
# 고객: 1회
# 관성: 1회
# 해외여행: 1회
# 컨돔: 1회
# 고열: 1회
# 빈둥거리: 1회
# 자넷: 1회
# 거주지: 1회
# 주인: 1회
# 영업일: 1회
# 시계: 1회
# 리자: 1회
# 굽기: 1회
# 산업: 1회
# 수리: 1회
# 제니: 1회
# 찾기: 1회
# 배: 1회
# 아침식사: 1회
# 달라: 1회
# 운영자: 1회
# 기록: 1회
# 라이트: 1회
# 리셉션: 1회
# 연차: 1회
# 비서: 1회
# 팔다리: 1회
# 문서: 1회
# 레잉: 1회
# 커즌: 1회
# 스케줄: 1회
# 고씨: 1회
# 속도: 1회
# 물리학: 1회
# 체증: 1회
# 죽지: 1회
# 반니: 1회
# 대변인: 1회
# 재고: 1회
# 둘: 1회
# 표정: 1회
# 일자리: 1회
# 자금: 1회
# 초대장: 1회
# 스타: 1회
# 쓰기: 1회
# 자가용: 1회
# 기후: 1회
# 점심시간: 1회
# 식욕: 1회
# 유명인: 1회
# 넬: 1회
# 역할: 1회
# 죽음: 1회
# 인터넷: 1회
# 배경: 1회
# 긁혔다: 1회
# 출근: 1회
# 숨쉬기: 1회
# 범인: 1회
# 리사: 1회
# 세대: 1회
# 하루: 1회
# 첫째: 1회
# 신앙: 1회
# 가지: 1회
# 두통: 1회
# 거래: 1회
# 경향: 1회
# 요리사: 1회
# 보고: 1회
# 퍼포먼스: 1회
# 계획: 1회
# 주어: 1회
# 결말: 1회
# 배송: 1회
# 의도: 1회
# 여자: 1회
# 연결: 1회
# 통증: 1회
# 교통사고: 1회
# 셋: 1회
# 친구: 1회
# 디자인: 1회
# 요하: 1회
# 해결: 1회
# 정보: 1회
# 정신: 1회
# 실: 1회
# 난관: 1회
# 주지: 1회
# 메일: 1회
# 얼음: 1회
# 부모님: 1회
# 하라: 1회
# 증가: 1회
# 집값: 1회
# 액수: 1회
# 밤: 1회
# 투자수익률: 1회
# 항해: 1회
# 견해: 1회
# 보도: 1회
# 기대: 1회
# 메리: 1회
# 데: 1회
# 개성: 1회
# 서류: 1회
# 저녁: 1회
# 프로그램: 1회
# 시간대: 1회
# 화차: 1회
# 예시: 1회
# 여사: 1회
# 무료: 1회
# 보라: 1회
# 확률: 1회
# 판결: 1회
# 디: 1회
# 옷차림: 1회
# 매너: 1회
# 참을성: 1회
# 원어민: 1회
# 리더: 1회
# 서비스: 1회
# 강도: 1회
# 제니스: 1회
# 르벤: 1회
# 치아: 1회
# 대해: 1회
# 엘리슨: 1회
# 콘텐츠: 1회
# 아이디어: 1회
# 결심: 1회
# 미열: 1회
# 선택: 1회
# 날짜: 1회
# 실력: 1회
# 집중: 1회
# 일정: 1회
# 스포츠: 1회
# 관리직: 1회
# 업무: 1회
# 역량: 1회
# 기능: 1회
# 처음: 1회
# 종이: 1회
# 경찰: 1회
# 연봉: 1회
# 오르다: 1회
# 반찬: 1회
# 기자: 1회
# 활동: 1회
# 참고서: 1회
# 자질: 1회
# 뇌우: 1회
# 선정: 1회
# 본인: 1회
# 왕씨: 1회
# 메기: 1회
# 사건: 1회
# 멜리사: 1회
# 약혼녀: 1회
# 프라이버시: 1회
# 비슨: 1회
# 활약: 1회
# 시대: 1회
# 사계절: 1회
# 걱정: 1회
# 계약금: 1회
# 숫자: 1회
# 예: 1회
# 결함: 1회
# 졸업생: 1회
# 물: 1회
# 정리: 1회
# 호텔: 1회
# 머리스타일: 1회
# 위로: 1회
# 시기: 1회
# 노래: 1회
# 협력: 1회
# 기사: 1회
# 젠니: 1회
# 처벌: 1회
# 방문자: 1회
# 수술: 1회
# 집주인: 1회
# 제품: 1회
# 수: 1회
# 운: 1회
# 켈리: 1회
# 부자: 1회
# 기계: 1회
# 의: 1회
# 허리: 1회
# 분위기: 1회
# 사려: 1회
# 확신: 1회
# 이상: 1회
# 치통: 1회
# 알기: 1회
# 엉망: 1회
# 메이크업: 1회
# 대화: 1회
# 팀: 1회
# 개념: 1회
# 줄거리: 1회
# 지연: 1회
# 야구공: 1회
# 의식: 1회
# 침실: 1회
# 집: 1회
# 다양성: 1회
# 릴리: 1회
# 여지: 1회
# 책임감: 1회
# 란씨: 1회
# 강조: 1회
# 루쓰: 1회
# 폭풍우: 1회
# 과제: 1회
# 태도: 1회
# 스티브: 1회
# 이웃: 1회
# 여행: 1회
# 채광: 1회
# 지역: 1회
# 기름기: 1회
# 전자: 1회
# 후자: 1회
# 아들: 1회
# 이빨: 1회
# 프레임: 1회
# 그림: 1회
# 사업가: 1회
# 판매원: 1회
# 로서: 1회
# 아이리스: 1회
# 장단점: 1회
# 강사: 1회
# 전문성: 1회
# 아이: 1회
# 판매량: 1회
# 요리: 1회
# 범: 1회
# 폴: 1회
# 힘: 1회
# 토핑: 1회
# 일몰: 1회
# 덤불: 1회
# 결과: 1회
# 발명자: 1회
# 다음: 1회
# 아이폰: 1회
# 엄마: 1회
# 럭키: 1회
# 각자: 1회
# 률: 1회
# 은행원: 1회
# 통근: 1회
# 취하: 1회
# 상품: 1회
# 잉크: 1회
# 급여: 1회
# 프랑스인: 1회
# 증상: 1회
# 학기: 1회
# 골치: 1회
# 웨이트리스: 1회
# 파트너: 1회
# 측: 1회
# 애완동물: 1회
# 줄리: 1회
# 한도: 1회
# 기한: 1회
# 세이: 1회
# 복통: 1회
# 이박사: 1회
# 사교성: 1회
# 컨디션: 1회
# 일부분: 1회
# 경력: 1회
# 성적: 1회
# 어조: 1회
# 김: 1회
# 장애: 1회
# 인생: 1회
# 분배: 1회
# 학습: 1회
# 스크램블에그: 1회
# 측정기: 1회
# 노력: 1회
# 장소: 2회
# 성격: 2회
# 대중: 2회
# 동안: 2회
# 가능성: 2회
# 느낌: 2회
# 밥: 2회
# 작업: 2회
# 호도: 2회
# 인기: 2회
# 취미: 2회
# 부인: 2회
# 출하: 2회
# 직무: 2회
# 또한: 2회
# 기간: 2회
# 팜링턴씨: 2회
# 상대방: 2회
# 날씨: 2회
# 질문: 2회
# 박사: 2회
# 부분: 2회
# 거리: 2회
# 스티븐: 2회
# 규칙: 2회
# 요구사항: 2회
# 시험: 2회
# 흡연: 2회
# 원인: 2회
# 간다: 2회
# 품질: 2회
# 로스: 2회
# 현재: 2회
# 서로: 2회
# 점: 2회
# 거기: 2회
# 책: 2회
# 이제: 2회
# 마음: 2회
# 직장: 2회
# 마리: 2회
# 열: 2회
# 능력: 2회
# 공간: 2회
# 월급: 2회
# 자리: 2회
# 셜리: 2회
# 휴식: 2회
# 사고: 2회
# 연락: 2회
# 짜증: 2회
# 상황: 2회
# 장: 2회
# 교통: 2회
# 케이트: 2회
# 현금: 2회
# 관: 2회
# 장점: 2회
# 장씨: 2회
# 파자마: 2회
# 생각: 2회
# 직원: 2회
# 방법: 2회
# 맥스: 2회
# 물건: 3회
# 남편: 3회
# 경우: 3회
# 옷: 3회
# 내용: 3회
# 위치: 3회
# 준비: 3회
# 양: 3회
# 변화: 3회
# 톰: 3회
# 가족: 3회
# 방식: 3회
# 돈: 3회
# 의견: 3회
# 체중: 3회
# 위해: 3회
# 율: 3회
# 선생님: 3회
# 스타일: 3회
# 예정: 3회
# 무엇: 3회
# 사항: 3회
# 도둑: 3회
# 기회: 3회
# 직업: 3회
# 데이비드: 3회
# 때: 3회
# 아내: 3회
# 필요: 4회
# 행동: 4회
# 요금: 4회
# 효과: 4회
# 딸: 4회
# 가치: 4회
# 여유: 4회
# 자격: 5회
# 생활: 5회
# 회사: 5회
# 일부: 5회
# 여성: 5회
# 자신감: 6회
# 어머니: 6회
# 누군가: 6회
# 적: 6회
# 하나: 6회
# 은: 6회
# 사실: 6회
# 거: 7회
# 몸: 7회
# 마이크: 7회
# 등: 8회
# 곳: 8회
# 의사: 8회
# 지금: 8회
# 문제: 9회
# 경험: 9회
# 씨: 10회
# 상태: 11회
# 가격: 11회
# 도움: 12회
# 의향: 12회
# 아버지: 12회
# 기분: 12회
# 비용: 16회
# 모두: 17회
# 시간: 17회
# 그: 19회
# 사람: 22회
# 남자: 24회
# 님: 30회
# 관심: 36회
# 것: 68회
# 이유: 90회
# 자신: 140회
# 그것: 223회
# 그녀: 299회

# %%
# 사람 이름으로 수기 검토해본 결과 영어 이름이 대화, 요약에 각각 한글로 번역되면서 달라진 것으로 보임.
# ex) steve -> 대화:스티븐, 요약:스티브

# %% [markdown]
# ### 영어로 작성된 행 확인

# %%
korean = '[가-힣]'

# 한글이 포함되지 않은 행을 필터링
# 한글 범위: 가-힣
english_only_df = train_df[~train_df['dialogue'].str.contains(korean, na=False)]
print(f'* dialogue\n{english_only_df}')

english_only_df = train_df[~train_df['summary'].str.contains(korean, na=False)]
print(f'\n* summary\n')
english_only_df
# Out:
# * dialogue
# Empty DataFrame
# Columns: [fname, dialogue, summary, topic]
# Index: []
#
# * summary
#              fname                                           dialogue  \
# 6812    train_6812  #Person1#: 안녕하세요, 할머니. 다시 만나서 정말 좋아요.\n#Person...
# 10896  train_10896  #Person1#: 기분이 어때?\n#Person2#: 나빠. 코가 계속 흐르고 이...
# 10897  train_10897  #Person1#: 유럽 투어에 대한 정보를 좀 주실 수 있나요?\n#Person2...
# 10900  train_10900  #Person1#: 좋아요, 테일러 씨, 시작해봅시다. 먼저, 마지막 직장에 대해 ...
#
#                                                  summary        topic
# 6812   Grandma gives Jack a racing car as a gift. The...  할머니를 데리러 가다
# 10896  Daniel got sick and Tom envies Daniel because ...     비밀을 유지하기
# 10897  #Person2#gives #Person1# some information on t...        유럽 투어
# 10900  #Person2# is interviewing Mr. Taylor. #Person2...        직장 면접

# %% [markdown]
# ##### 영어 summary 삭제

# %%
train_df = train_df[train_df['summary'].str.contains(korean, na=False)]

# %% [markdown]
# # 전처리 된 train 데이터셋 저장

# %%
train_df.reset_index(drop=True, inplace=True)
train_df
# Out:
#              fname                                           dialogue  \
# 0          train_0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1          train_1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2          train_2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3          train_3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4          train_4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
# ...            ...                                                ...
# 12439  train_12455  #Person1#: 실례합니다. 맨체스터 출신의 그린 씨이신가요?\n#Person2...
# 12440  train_12456  #Person1#: 이윙 씨가 우리가 컨퍼런스 센터에 오후 4시에 도착해야 한다고 ...
# 12441  train_12457  #Person1#: 오늘 어떻게 도와드릴까요?\n#Person2#: 차를 빌리고 싶...
# 12442  train_12458  #Person1#: 오늘 좀 행복해 보이지 않아. 무슨 일 있어?\n#Person2...
# 12443  train_12459  #Person1#: 엄마, 다음 토요일에 이 삼촌네 가족을 방문하기 위해 비행기를 ...
#
#                                                  summary     topic
# 0      스미스씨가 건강검진을 받고 있고, 호킨스 의사는 매년 건강검진을 받는 것을 권장합니...   건강검진 받기
# 1      파커 부인이 리키를 데리고 백신 접종을 하러 갔다. 피터스 박사는 기록을 확인한 후...        백신
# 2      #Person1#은 열쇠 한 묶음을 찾고 있고, 그것을 찾기 위해 #Person2#...     열쇠 찾기
# 3      #Person1#은 #Person2#가 여자친구가 있고 그녀와 결혼할 것이라는 사실...  여자친구가 있다
# 4      말릭이 니키에게 춤을 요청한다. 말릭이 발을 밟는 것을 신경 쓰지 않는다면 니키는 ...        댄스
# ...                                                  ...       ...
# 12439  탄 링은 흰머리와 수염으로 쉽게 인식되는 그린 씨를 만나 호텔로 데려갈 예정입니다....  누군가를 태우다
# 12440  #Person1#과 #Person2#는 이윙 씨가 늦지 않도록 요청했기 때문에 컨퍼...   컨퍼런스 센터
# 12441       #Person2#는 #Person1#의 도움으로 5일 동안 소형 차를 빌립니다.      차 렌트
# 12442  #Person2#의 엄마가 일자리를 잃었다. #Person2#는 엄마가 우울해하지 ...        실직
# 12443  #Person1#은 다음 토요일에 이 삼촌네를 방문할 때 가방을 어떻게 싸야 할지 ...      짐 싸기
#
# [12444 rows x 4 columns]

# %%
train_df.to_csv('./data/train_cleaned.csv', index=False)
